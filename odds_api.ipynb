# %%
import requests
import json
import pandas as pd
from datetime import datetime
api_key = 'f7895bc3ff4930480444c1033ddbe37f'

SPORT = 'basketball_ncaab' # use the sport_key from the /sports endpoint below, or use 'upcoming' to see the next 8 games across all sports

HOST = f'https://api.the-odds-api.com'

REGIONS = 'us' # uk | us | eu | au. Multiple can be specified if comma delimited

MARKETS = 'h2h, spreads, totals, outrights' # h2h | spreads | totals. Multiple can be specified if comma delimited

ODDS_FORMAT = 'american' # decimal | american

DATE_FORMAT = 'iso'

sports_response = requests.get(
    f'{HOST}/v4/sports',
    params={
        'api_key': api_key,
        'regions': REGIONS,
        'markets': MARKETS,
        'oddsFormat': ODDS_FORMAT,
        'dateFormat': DATE_FORMAT,
    }
)
odds_response = requests.get(
    f'{HOST}/v4/sports/{SPORT}/odds',
    params={
        'api_key': api_key,
        'regions': REGIONS,
        'markets': MARKETS,
        'oddsFormat': ODDS_FORMAT,
        'dateFormat': DATE_FORMAT,
    }
)

if odds_response.status_code != 200:
    print(f'Failed to get odds: status_code {odds_response.status_code}, response body {odds_response.text}')

else:
    odds_json = odds_response.json()
# Out:
# Failed to get odds: status_code 422, response body {"message":"One or more markets invalid. Check the docs https://the-odds-api.com/liveapi/guides/v4/"}

# %%
sports_keys = pd.json_normalize(sports_response.json())['key'].to_list()

odds_responses = {
    sport: requests.get(
    f'{HOST}/v4/sports/{sport}/odds',
    params={
        'api_key': api_key,
        'regions': REGIONS,
        'oddsFormat': ODDS_FORMAT,
        'dateFormat': DATE_FORMAT,
    } 
).json() for sport in sports_keys
}

# %%
odds_responses
# Out:
# {'americanfootball_ncaaf': [{'id': '329ee4daba3514dce8018d5768e5043f',
#    'sport_key': 'americanfootball_ncaaf',
#    'sport_title': 'NCAAF',
#    'commence_time': '2024-08-24T18:30:00Z',
#    'home_team': 'Georgia Tech Yellow Jackets',
#    'away_team': 'Florida State Seminoles',
#    'bookmakers': [{'key': 'fanduel',
#      'title': 'FanDuel',
#      'last_update': '2024-02-17T09:14:16Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:14:16Z',
#        'outcomes': [{'name': 'Florida State Seminoles', 'price': -480},
#         {'name': 'Georgia Tech Yellow Jackets', 'price': 360}]}]}]},
#   {'id': '6d4fa722a24acf375db350092cf688b9',
#    'sport_key': 'americanfootball_ncaaf',
#    'sport_title': 'NCAAF',
#    'commence_time': '2024-08-31T19:30:00Z',
#    'home_team': 'Colorado Buffaloes',
#    'away_team': 'North Dakota State Bison',
#    'bookmakers': [{'key': 'fanduel',
#      'title': 'FanDuel',
#      'last_update': '2024-02-17T09:14:16Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:14:16Z',
#        'outcomes': [{'name': 'Colorado Buffaloes', 'price': -310},
#         {'name': 'North Dakota State Bison', 'price': 245}]}]}]},
#   {'id': '0154080042357cf8dd2cf7f55c132885',
#    'sport_key': 'americanfootball_ncaaf',
#    'sport_title': 'NCAAF',
#    'commence_time': '2024-08-31T19:30:00Z',
#    'home_team': 'Texas A&M Aggies',
#    'away_team': 'Notre Dame Fighting Irish',
#    'bookmakers': [{'key': 'fanduel',
#      'title': 'FanDuel',
#      'last_update': '2024-02-17T09:14:16Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:14:16Z',
#        'outcomes': [{'name': 'Notre Dame Fighting Irish', 'price': -102},
#         {'name': 'Texas A&M Aggies', 'price': -118}]}]}]},
#   {'id': 'b7cf707bbb8579f69e1eb332ff5d5ce8',
#    'sport_key': 'americanfootball_ncaaf',
#    'sport_title': 'NCAAF',
#    'commence_time': '2024-09-01T00:00:00Z',
#    'home_team': 'Georgia Bulldogs',
#    'away_team': 'Clemson Tigers',
#    'bookmakers': [{'key': 'fanduel',
#      'title': 'FanDuel',
#      'last_update': '2024-02-17T09:14:16Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:14:16Z',
#        'outcomes': [{'name': 'Clemson Tigers', 'price': 420},
#         {'name': 'Georgia Bulldogs', 'price': -580}]}]}]},
#   {'id': 'ed94b4cac3505c1011053cc8b9a3fdb5',
#    'sport_key': 'americanfootball_ncaaf',
#    'sport_title': 'NCAAF',
#    'commence_time': '2024-09-01T23:30:00Z',
#    'home_team': 'USC Trojans',
#    'away_team': 'LSU Tigers',
#    'bookmakers': [{'key': 'fanduel',
#      'title': 'FanDuel',
#      'last_update': '2024-02-17T09:14:16Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:14:16Z',
#        'outcomes': [{'name': 'LSU Tigers', 'price': -210},
#         {'name': 'USC Trojans', 'price': 172}]}]}]},
#   {'id': '8e3045f419101edb642054549768ac67',
#    'sport_key': 'americanfootball_ncaaf',
#    'sport_title': 'NCAAF',
#    'commence_time': '2024-09-07T16:00:00Z',
#    'home_team': 'Michigan Wolverines',
#    'away_team': 'Texas Longhorns',
#    'bookmakers': [{'key': 'fanduel',
#      'title': 'FanDuel',
#      'last_update': '2024-02-17T09:14:16Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:14:16Z',
#        'outcomes': [{'name': 'Michigan Wolverines', 'price': 116},
#         {'name': 'Texas Longhorns', 'price': -140}]}]}]},
#   {'id': 'ccab62d689b7fa48fe8923801105f436',
#    'sport_key': 'americanfootball_ncaaf',
#    'sport_title': 'NCAAF',
#    'commence_time': '2024-09-28T23:00:00Z',
#    'home_team': 'Alabama Crimson Tide',
#    'away_team': 'Georgia Bulldogs',
#    'bookmakers': [{'key': 'fanduel',
#      'title': 'FanDuel',
#      'last_update': '2024-02-17T09:14:16Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:14:16Z',
#        'outcomes': [{'name': 'Alabama Crimson Tide', 'price': 140},
#         {'name': 'Georgia Bulldogs', 'price': -170}]}]}]},
#   {'id': 'e34e1ba3c038f2fb8739318355793866',
#    'sport_key': 'americanfootball_ncaaf',
#    'sport_title': 'NCAAF',
#    'commence_time': '2024-10-05T16:00:00Z',
#    'home_team': 'Washington Huskies',
#    'away_team': 'Michigan Wolverines',
#    'bookmakers': [{'key': 'fanduel',
#      'title': 'FanDuel',
#      'last_update': '2024-02-17T09:14:16Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:14:16Z',
#        'outcomes': [{'name': 'Michigan Wolverines', 'price': -465},
#         {'name': 'Washington Huskies', 'price': 350}]}]}]},
#   {'id': '3e401f110827c69c08fdcd237d08bdb9',
#    'sport_key': 'americanfootball_ncaaf',
#    'sport_title': 'NCAAF',
#    'commence_time': '2024-10-12T16:00:00Z',
#    'home_team': 'Oregon Ducks',
#    'away_team': 'Ohio State Buckeyes',
#    'bookmakers': [{'key': 'fanduel',
#      'title': 'FanDuel',
#      'last_update': '2024-02-17T09:14:16Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:14:16Z',
#        'outcomes': [{'name': 'Ohio State Buckeyes', 'price': -113},
#         {'name': 'Oregon Ducks', 'price': -106}]}]}]},
#   {'id': 'd4637f010f52e3d47c1efa4b2be0ca5b',
#    'sport_key': 'americanfootball_ncaaf',
#    'sport_title': 'NCAAF',
#    'commence_time': '2024-10-12T16:00:00Z',
#    'home_team': 'Oklahoma Sooners',
#    'away_team': 'Texas Longhorns',
#    'bookmakers': []},
#   {'id': '4ebc66185861a2a27f06ebb8f8d9ad83',
#    'sport_key': 'americanfootball_ncaaf',
#    'sport_title': 'NCAAF',
#    'commence_time': '2024-10-19T16:00:00Z',
#    'home_team': 'Texas Longhorns',
#    'away_team': 'Georgia Bulldogs',
#    'bookmakers': []},
#   {'id': '98b1e9e3344e4fab2142f7579cd8229e',
#    'sport_key': 'americanfootball_ncaaf',
#    'sport_title': 'NCAAF',
#    'commence_time': '2024-11-09T17:00:00Z',
#    'home_team': 'Ole Miss Rebels',
#    'away_team': 'Georgia Bulldogs',
#    'bookmakers': [{'key': 'fanduel',
#      'title': 'FanDuel',
#      'last_update': '2024-02-17T09:14:16Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:14:16Z',
#        'outcomes': [{'name': 'Georgia Bulldogs', 'price': -164},
#         {'name': 'Ole Miss Rebels', 'price': 136}]}]}]},
#   {'id': '5ec11b006e7d7e919cb63aa1f4a5ffaa',
#    'sport_key': 'americanfootball_ncaaf',
#    'sport_title': 'NCAAF',
#    'commence_time': '2024-11-10T00:00:00Z',
#    'home_team': 'LSU Tigers',
#    'away_team': 'Alabama Crimson Tide',
#    'bookmakers': [{'key': 'fanduel',
#      'title': 'FanDuel',
#      'last_update': '2024-02-17T09:14:16Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:14:16Z',
#        'outcomes': [{'name': 'Alabama Crimson Tide', 'price': 106},
#         {'name': 'LSU Tigers', 'price': -128}]}]}]},
#   {'id': '27a8846b7b9d56b5360098f7ba184cf0',
#    'sport_key': 'americanfootball_ncaaf',
#    'sport_title': 'NCAAF',
#    'commence_time': '2024-11-30T17:00:00Z',
#    'home_team': 'Ohio State Buckeyes',
#    'away_team': 'Michigan Wolverines',
#    'bookmakers': [{'key': 'fanduel',
#      'title': 'FanDuel',
#      'last_update': '2024-02-17T09:14:16Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:14:16Z',
#        'outcomes': [{'name': 'Michigan Wolverines', 'price': 225},
#         {'name': 'Ohio State Buckeyes', 'price': -280}]}]}]}],
#  'americanfootball_ncaaf_championship_winner': [{'id': 'be95dd8b58f4a0c6de52611048d644bc',
#    'has_outrights': True,
#    'sport_key': 'americanfootball_ncaaf_championship_winner',
#    'sport_title': 'NCAAF Championship Winner',
#    'commence_time': '2025-01-15T01:00:00Z',
#    'home_team': None,
#    'away_team': None,
#    'bookmakers': [{'key': 'betonlineag',
#      'title': 'BetOnline.ag',
#      'last_update': '2024-02-17T09:09:45Z',
#      'markets': [{'key': 'outrights',
#        'last_update': '2024-02-17T09:09:45Z',
#        'outcomes': [{'name': 'Georgia Bulldogs', 'price': 350},
#         {'name': 'Ohio State Buckeyes', 'price': 550},
#         {'name': 'Texas Longhorns', 'price': 700},
#         {'name': 'Oregon Ducks', 'price': 800},
#         {'name': 'Alabama Crimson Tide', 'price': 1100},
#         {'name': 'Ole Miss Rebels', 'price': 1400},
#         {'name': 'Michigan Wolverines', 'price': 1600},
#         {'name': 'LSU Tigers', 'price': 1600},
#         {'name': 'Florida State Seminoles', 'price': 2200},
#         {'name': 'Penn State Nittany Lions', 'price': 3300},
#         {'name': 'Notre Dame Fighting Irish', 'price': 3300},
#         {'name': 'Texas A&M Aggies', 'price': 3300},
#         {'name': 'Missouri Tigers', 'price': 3300},
#         {'name': 'Clemson Tigers', 'price': 3500},
#         {'name': 'Oklahoma Sooners', 'price': 3500},
#         {'name': 'Tennessee Volunteers', 'price': 3500},
#         {'name': 'USC Trojans', 'price': 4500},
#         {'name': 'Washington Huskies', 'price': 6000},
#         {'name': 'Kansas State Wildcats', 'price': 6600},
#         {'name': 'Miami Hurricanes', 'price': 6600},
#         {'name': 'Utah Utes', 'price': 7500},
#         {'name': 'Auburn Tigers', 'price': 10000},
#         {'name': 'Arizona Wildcats', 'price': 10000},
#         {'name': 'Louisville Cardinals', 'price': 15000},
#         {'name': 'Florida Gators', 'price': 15000},
#         {'name': 'Nebraska Cornhuskers', 'price': 15000},
#         {'name': 'Texas Tech Red Raiders', 'price': 20000},
#         {'name': 'Wisconsin Badgers', 'price': 20000},
#         {'name': 'Kansas Jayhawks', 'price': 20000},
#         {'name': 'Kentucky Wildcats', 'price': 20000},
#         {'name': 'Oklahoma State Cowboys', 'price': 20000},
#         {'name': 'SMU Mustangs', 'price': 20000},
#         {'name': 'Arkansas Razorbacks', 'price': 25000},
#         {'name': 'North Carolina Tar Heels', 'price': 25000},
#         {'name': 'Colorado Buffaloes', 'price': 25000},
#         {'name': 'South Carolina Gamecocks', 'price': 25000},
#         {'name': 'NC State Wolfpack', 'price': 25000},
#         {'name': 'UCLA Bruins', 'price': 30000},
#         {'name': 'TCU Horned Frogs', 'price': 30000},
#         {'name': 'UCF Knights', 'price': 30000},
#         {'name': 'Iowa State Cyclones', 'price': 40000},
#         {'name': 'Maryland Terrapins', 'price': 40000},
#         {'name': 'Iowa Hawkeyes', 'price': 40000},
#         {'name': 'Michigan State Spartans', 'price': 50000},
#         {'name': 'James Madison Dukes', 'price': 50000},
#         {'name': 'Virginia Tech Hokies', 'price': 50000},
#         {'name': 'Oregon State Beavers', 'price': 50000},
#         {'name': 'West Virginia Mountaineers', 'price': 50000},
#         {'name': 'Liberty Flames', 'price': 50000},
#         {'name': 'California Golden Bears', 'price': 50000},
#         {'name': 'Mississippi State Bulldogs', 'price': 50000},
#         {'name': 'Boise State Broncos', 'price': 50000},
#         {'name': 'Cincinnati Bearcats', 'price': 60000},
#         {'name': 'Baylor Bears', 'price': 60000},
#         {'name': 'Tulane Green Wave', 'price': 75000},
#         {'name': 'Troy Trojans', 'price': 75000},
#         {'name': 'Virginia Cavaliers', 'price': 75000},
#         {'name': 'Boston College Eagles', 'price': 75000},
#         {'name': 'Arizona State Sun Devils', 'price': 75000},
#         {'name': 'Rutgers Scarlet Knights', 'price': 75000},
#         {'name': 'Pittsburgh Panthers', 'price': 100000},
#         {'name': 'Illinois Fighting Illini', 'price': 100000},
#         {'name': 'Minnesota Golden Gophers', 'price': 100000},
#         {'name': 'Sam Houston State Bearkats', 'price': 100000},
#         {'name': 'Kent State Golden Flashes', 'price': 100000},
#         {'name': 'Houston Cougars', 'price': 100000},
#         {'name': 'Colorado State Rams', 'price': 100000},
#         {'name': 'BYU Cougars', 'price': 100000},
#         {'name': 'Rice Owls', 'price': 100000},
#         {'name': 'Western Kentucky Hilltoppers', 'price': 100000},
#         {'name': 'Vanderbilt Commodores', 'price': 100000},
#         {'name': 'Wake Forest Demon Deacons', 'price': 100000},
#         {'name': 'Miami (OH) RedHawks', 'price': 100000},
#         {'name': 'Appalachian State Mountaineers', 'price': 100000},
#         {'name': 'Bowling Green Falcons', 'price': 100000},
#         {'name': 'East Carolina Pirates', 'price': 100000},
#         {'name': 'San Diego State Aztecs', 'price': 100000},
#         {'name': 'Arkansas State Red Wolves', 'price': 100000},
#         {'name': 'San Jose State Spartans', 'price': 100000},
#         {'name': 'Georgia Tech Yellow Jackets', 'price': 100000},
#         {'name': 'New Mexico Lobos', 'price': 100000},
#         {'name': 'Western Michigan Broncos', 'price': 100000},
#         {'name': 'Ball State Cardinals', 'price': 100000},
#         {'name': 'UL Monroe Warhawks', 'price': 100000},
#         {'name': 'Texas State Bobcats', 'price': 100000},
#         {'name': 'Memphis Tigers', 'price': 100000},
#         {'name': 'Eastern Michigan Eagles', 'price': 100000},
#         {'name': 'Louisiana Ragin Cajuns', 'price': 100000},
#         {'name': 'Duke Blue Devils', 'price': 100000},
#         {'name': 'Wyoming Cowboys', 'price': 100000},
#         {'name': 'UNLV Rebels', 'price': 100000},
#         {'name': 'Florida International Panthers', 'price': 100000},
#         {'name': 'Buffalo Bulls', 'price': 100000},
#         {'name': 'Stanford Cardinal', 'price': 100000},
#         {'name': 'Marshall Thundering Herd', 'price': 100000},
#         {'name': 'Ohio Bobcats', 'price': 100000},
#         {'name': 'South Alabama Jaguars', 'price': 100000},
#         {'name': 'Tulsa Golden Hurricane', 'price': 100000},
#         {'name': 'Army Black Knights', 'price': 100000},
#         {'name': 'Toledo Rockets', 'price': 100000},
#         {'name': 'Central Michigan Chippewas', 'price': 100000},
#         {'name': 'UTEP Miners', 'price': 100000},
#         {'name': 'Air Force Falcons', 'price': 100000},
#         {'name': 'UTSA Roadrunners', 'price': 100000},
#         {'name': 'Nevada Wolf Pack', 'price': 100000},
#         {'name': 'Coastal Carolina Chanticleers', 'price': 100000},
#         {'name': 'UAB Blazers', 'price': 100000},
#         {'name': 'UConn Huskies', 'price': 100000},
#         {'name': 'Florida Atlantic Owls', 'price': 100000},
#         {'name': 'Old Dominion Monarchs', 'price': 100000},
#         {'name': 'North Texas Mean Green', 'price': 100000},
#         {'name': 'UMass Minutemen', 'price': 100000},
#         {'name': 'Utah State Aggies', 'price': 100000},
#         {'name': 'Syracuse Orange', 'price': 100000},
#         {'name': 'Louisiana Tech Bulldogs', 'price': 100000},
#         {'name': 'Charlotte 49ers', 'price': 100000},
#         {'name': 'Southern Mississippi Golden Eagles', 'price': 100000},
#         {'name': 'Georgia State Panthers', 'price': 100000},
#         {'name': 'Fresno State Bulldogs', 'price': 100000},
#         {'name': 'Temple Owls', 'price': 100000},
#         {'name': 'Purdue Boilermakers', 'price': 100000},
#         {'name': 'Washington State Cougars', 'price': 100000},
#         {'name': 'Indiana Hoosiers', 'price': 100000},
#         {'name': 'Akron Zips', 'price': 100000},
#         {'name': 'Hawaii Rainbow Warriors', 'price': 100000},
#         {'name': 'South Florida Bulls', 'price': 100000},
#         {'name': 'Jacksonville State Gamecocks', 'price': 100000},
#         {'name': 'Middle Tennessee Blue Raiders', 'price': 100000},
#         {'name': 'Georgia Southern Eagles', 'price': 100000},
#         {'name': 'Northern Illinois Huskies', 'price': 100000}]}]},
#     {'key': 'fanduel',
#      'title': 'FanDuel',
#      'last_update': '2024-02-17T09:09:26Z',
#      'markets': [{'key': 'outrights',
#        'last_update': '2024-02-17T09:09:26Z',
#        'outcomes': [{'name': 'Georgia Bulldogs', 'price': 300},
#         {'name': 'Ohio State Buckeyes', 'price': 500},
#         {'name': 'Texas Longhorns', 'price': 700},
#         {'name': 'Oregon Ducks', 'price': 850},
#         {'name': 'Alabama Crimson Tide', 'price': 1200},
#         {'name': 'LSU Tigers', 'price': 1500},
#         {'name': 'Michigan Wolverines', 'price': 1500},
#         {'name': 'Ole Miss Rebels', 'price': 1500},
#         {'name': 'Florida State Seminoles', 'price': 2000},
#         {'name': 'Penn State Nittany Lions', 'price': 2500},
#         {'name': 'Notre Dame Fighting Irish', 'price': 2500},
#         {'name': 'Missouri Tigers', 'price': 3000},
#         {'name': 'Clemson Tigers', 'price': 3000},
#         {'name': 'Tennessee Volunteers', 'price': 3000},
#         {'name': 'Texas A&M Aggies', 'price': 4000},
#         {'name': 'USC Trojans', 'price': 4000},
#         {'name': 'Utah Utes', 'price': 6000},
#         {'name': 'Miami Hurricanes', 'price': 6000},
#         {'name': 'Oklahoma Sooners', 'price': 6000},
#         {'name': 'Kansas State Wildcats', 'price': 6000},
#         {'name': 'Auburn Tigers', 'price': 10000},
#         {'name': 'Washington Huskies', 'price': 10000},
#         {'name': 'Louisville Cardinals', 'price': 12000},
#         {'name': 'Arizona Wildcats', 'price': 15000},
#         {'name': 'Kansas Jayhawks', 'price': 20000},
#         {'name': 'Texas Tech Red Raiders', 'price': 20000},
#         {'name': 'Kentucky Wildcats', 'price': 20000},
#         {'name': 'Florida Gators', 'price': 20000},
#         {'name': 'SMU Mustangs', 'price': 20000},
#         {'name': 'North Carolina Tar Heels', 'price': 25000},
#         {'name': 'Wisconsin Badgers', 'price': 25000},
#         {'name': 'Arkansas Razorbacks', 'price': 25000},
#         {'name': 'Iowa Hawkeyes', 'price': 25000},
#         {'name': 'South Carolina Gamecocks', 'price': 25000},
#         {'name': 'NC State Wolfpack', 'price': 25000},
#         {'name': 'Nebraska Cornhuskers', 'price': 30000},
#         {'name': 'TCU Horned Frogs', 'price': 30000},
#         {'name': 'Iowa State Cyclones', 'price': 30000},
#         {'name': 'Colorado Buffaloes', 'price': 30000},
#         {'name': 'UCF Knights', 'price': 30000},
#         {'name': 'Oklahoma State Cowboys', 'price': 30000},
#         {'name': 'Maryland Terrapins', 'price': 40000},
#         {'name': 'Virginia Tech Hokies', 'price': 50000},
#         {'name': 'Oregon State Beavers', 'price': 50000},
#         {'name': 'West Virginia Mountaineers', 'price': 50000},
#         {'name': 'Michigan State Spartans', 'price': 50000},
#         {'name': 'Liberty Flames', 'price': 50000},
#         {'name': 'UCLA Bruins', 'price': 50000},
#         {'name': 'California Golden Bears', 'price': 50000},
#         {'name': 'Boise State Broncos', 'price': 50000},
#         {'name': 'Memphis Tigers', 'price': 60000},
#         {'name': 'Mississippi State Bulldogs', 'price': 60000},
#         {'name': 'James Madison Dukes', 'price': 60000},
#         {'name': 'Baylor Bears', 'price': 60000},
#         {'name': 'Arizona State Sun Devils', 'price': 80000},
#         {'name': 'Cincinnati Bearcats', 'price': 80000},
#         {'name': 'Virginia Cavaliers', 'price': 80000},
#         {'name': 'Tulane Green Wave', 'price': 80000},
#         {'name': 'Syracuse Orange', 'price': 80000},
#         {'name': 'Troy Trojans', 'price': 80000},
#         {'name': 'Sam Houston State Bearkats', 'price': 100000},
#         {'name': 'Kent State Golden Flashes', 'price': 100000},
#         {'name': 'Houston Cougars', 'price': 100000},
#         {'name': 'Colorado State Rams', 'price': 100000},
#         {'name': 'BYU Cougars', 'price': 100000},
#         {'name': 'Rice Owls', 'price': 100000},
#         {'name': 'Western Kentucky Hilltoppers', 'price': 100000},
#         {'name': 'Vanderbilt Commodores', 'price': 100000},
#         {'name': 'Wake Forest Demon Deacons', 'price': 100000},
#         {'name': 'Miami (OH) RedHawks', 'price': 100000},
#         {'name': 'Appalachian State Mountaineers', 'price': 100000},
#         {'name': 'Bowling Green Falcons', 'price': 100000},
#         {'name': 'East Carolina Pirates', 'price': 100000},
#         {'name': 'San Diego State Aztecs', 'price': 100000},
#         {'name': 'Arkansas State Red Wolves', 'price': 100000},
#         {'name': 'San Jose State Spartans', 'price': 100000},
#         {'name': 'Pittsburgh Panthers', 'price': 100000},
#         {'name': 'Georgia Tech Yellow Jackets', 'price': 100000},
#         {'name': 'New Mexico Lobos', 'price': 100000},
#         {'name': 'Western Michigan Broncos', 'price': 100000},
#         {'name': 'Ball State Cardinals', 'price': 100000},
#         {'name': 'UL Monroe Warhawks', 'price': 100000},
#         {'name': 'Texas State Bobcats', 'price': 100000},
#         {'name': 'Eastern Michigan Eagles', 'price': 100000},
#         {'name': 'Louisiana Ragin Cajuns', 'price': 100000},
#         {'name': 'Duke Blue Devils', 'price': 100000},
#         {'name': 'New Mexico State Aggies', 'price': 100000},
#         {'name': 'Navy Midshipmen', 'price': 100000},
#         {'name': 'Wyoming Cowboys', 'price': 100000},
#         {'name': 'UNLV Rebels', 'price': 100000},
#         {'name': 'Buffalo Bulls', 'price': 100000},
#         {'name': 'Stanford Cardinal', 'price': 100000},
#         {'name': 'Marshall Thundering Herd', 'price': 100000},
#         {'name': 'Northwestern Wildcats', 'price': 100000},
#         {'name': 'Ohio Bobcats', 'price': 100000},
#         {'name': 'Boston College Eagles', 'price': 100000},
#         {'name': 'South Alabama Jaguars', 'price': 100000},
#         {'name': 'Tulsa Golden Hurricane', 'price': 100000},
#         {'name': 'Army Black Knights', 'price': 100000},
#         {'name': 'Toledo Rockets', 'price': 100000},
#         {'name': 'Central Michigan Chippewas', 'price': 100000},
#         {'name': 'UTEP Miners', 'price': 100000},
#         {'name': 'Air Force Falcons', 'price': 100000},
#         {'name': 'UTSA Roadrunners', 'price': 100000},
#         {'name': 'Nevada Wolf Pack', 'price': 100000},
#         {'name': 'Coastal Carolina Chanticleers', 'price': 100000},
#         {'name': 'UAB Blazers', 'price': 100000},
#         {'name': 'UConn Huskies', 'price': 100000},
#         {'name': 'Florida Atlantic Owls', 'price': 100000},
#         {'name': 'Old Dominion Monarchs', 'price': 100000},
#         {'name': 'North Texas Mean Green', 'price': 100000},
#         {'name': 'UMass Minutemen', 'price': 100000},
#         {'name': 'Utah State Aggies', 'price': 100000},
#         {'name': 'Louisiana Tech Bulldogs', 'price': 100000},
#         {'name': 'Charlotte 49ers', 'price': 100000},
#         {'name': 'Illinois Fighting Illini', 'price': 100000},
#         {'name': 'Southern Mississippi Golden Eagles', 'price': 100000},
#         {'name': 'Georgia State Panthers', 'price': 100000},
#         {'name': 'Fresno State Bulldogs', 'price': 100000},
#         {'name': 'Temple Owls', 'price': 100000},
#         {'name': 'Purdue Boilermakers', 'price': 100000},
#         {'name': 'Washington State Cougars', 'price': 100000},
#         {'name': 'Indiana Hoosiers', 'price': 100000},
#         {'name': 'Minnesota Golden Gophers', 'price': 100000},
#         {'name': 'Akron Zips', 'price': 100000},
#         {'name': 'Hawaii Rainbow Warriors', 'price': 100000},
#         {'name': 'South Florida Bulls', 'price': 100000},
#         {'name': 'Jacksonville State Gamecocks', 'price': 100000},
#         {'name': 'Middle Tennessee Blue Raiders', 'price': 100000},
#         {'name': 'Georgia Southern Eagles', 'price': 100000},
#         {'name': 'Northern Illinois Huskies', 'price': 100000},
#         {'name': 'Florida International Panthers', 'price': 100000}]}]},
#     {'key': 'williamhill_us',
#      'title': 'Caesars',
#      'last_update': '2024-02-17T09:12:58Z',
#      'markets': [{'key': 'outrights',
#        'last_update': '2024-02-17T09:12:58Z',
#        'outcomes': [{'name': 'Georgia Bulldogs', 'price': 350},
#         {'name': 'Ohio State Buckeyes', 'price': 400},
#         {'name': 'Texas Longhorns', 'price': 800},
#         {'name': 'Oregon Ducks', 'price': 1000},
#         {'name': 'Alabama Crimson Tide', 'price': 1100},
#         {'name': 'LSU Tigers', 'price': 1300},
#         {'name': 'Ole Miss Rebels', 'price': 1400},
#         {'name': 'Michigan Wolverines', 'price': 1600},
#         {'name': 'Florida State Seminoles', 'price': 2000},
#         {'name': 'USC Trojans', 'price': 2200},
#         {'name': 'Notre Dame Fighting Irish', 'price': 2200},
#         {'name': 'Penn State Nittany Lions', 'price': 2500},
#         {'name': 'Clemson Tigers', 'price': 2800},
#         {'name': 'Tennessee Volunteers', 'price': 3500},
#         {'name': 'Oklahoma Sooners', 'price': 4000},
#         {'name': 'Missouri Tigers', 'price': 4000},
#         {'name': 'Texas A&M Aggies', 'price': 4000},
#         {'name': 'Kansas State Wildcats', 'price': 5000},
#         {'name': 'Arizona Wildcats', 'price': 5000},
#         {'name': 'Washington Huskies', 'price': 6000},
#         {'name': 'Miami Hurricanes', 'price': 6000},
#         {'name': 'Colorado Buffaloes', 'price': 7500},
#         {'name': 'Louisville Cardinals', 'price': 7500},
#         {'name': 'Utah Utes', 'price': 7500},
#         {'name': 'SMU Mustangs', 'price': 10000},
#         {'name': 'Auburn Tigers', 'price': 10000},
#         {'name': 'Nebraska Cornhuskers', 'price': 11000},
#         {'name': 'Kentucky Wildcats', 'price': 12500},
#         {'name': 'NC State Wolfpack', 'price': 12500},
#         {'name': 'Iowa Hawkeyes', 'price': 12500},
#         {'name': 'North Carolina Tar Heels', 'price': 12500},
#         {'name': 'Kansas Jayhawks', 'price': 12500},
#         {'name': 'Oklahoma State Cowboys', 'price': 12500},
#         {'name': 'Wisconsin Badgers', 'price': 15000},
#         {'name': 'UCLA Bruins', 'price': 20000},
#         {'name': 'Florida Gators', 'price': 20000},
#         {'name': 'Texas Tech Red Raiders', 'price': 20000},
#         {'name': 'UCF Knights', 'price': 20000},
#         {'name': 'Iowa State Cyclones', 'price': 25000},
#         {'name': 'Boise State Broncos', 'price': 25000},
#         {'name': 'Tulane Green Wave', 'price': 25000},
#         {'name': 'Michigan State Spartans', 'price': 25000},
#         {'name': 'Maryland Terrapins', 'price': 30000},
#         {'name': 'Virginia Tech Hokies', 'price': 30000},
#         {'name': 'South Carolina Gamecocks', 'price': 30000},
#         {'name': 'TCU Horned Frogs', 'price': 30000},
#         {'name': 'Liberty Flames', 'price': 30000},
#         {'name': 'Duke Blue Devils', 'price': 40000},
#         {'name': 'Boston College Eagles', 'price': 40000},
#         {'name': 'UTSA Roadrunners', 'price': 40000},
#         {'name': 'Georgia Tech Yellow Jackets', 'price': 40000},
#         {'name': 'Arizona State Sun Devils', 'price': 40000},
#         {'name': 'California Golden Bears', 'price': 50000},
#         {'name': 'Arkansas Razorbacks', 'price': 50000},
#         {'name': 'West Virginia Mountaineers', 'price': 50000},
#         {'name': 'Troy Trojans', 'price': 50000},
#         {'name': 'Oregon State Beavers', 'price': 75000},
#         {'name': 'James Madison Dukes', 'price': 75000},
#         {'name': 'Wake Forest Demon Deacons', 'price': 75000},
#         {'name': 'Baylor Bears', 'price': 75000},
#         {'name': 'Syracuse Orange', 'price': 75000},
#         {'name': 'San Jose State Spartans', 'price': 75000},
#         {'name': 'UNLV Rebels', 'price': 75000},
#         {'name': 'Washington State Cougars', 'price': 75000},
#         {'name': 'Air Force Falcons', 'price': 100000},
#         {'name': 'Fresno State Bulldogs', 'price': 100000},
#         {'name': 'Houston Cougars', 'price': 100000},
#         {'name': 'Northwestern Wildcats', 'price': 100000},
#         {'name': 'Pittsburgh Panthers', 'price': 100000},
#         {'name': 'Utah State Aggies', 'price': 100000},
#         {'name': 'Colorado State Rams', 'price': 100000},
#         {'name': 'BYU Cougars', 'price': 100000},
#         {'name': 'Coastal Carolina Chanticleers', 'price': 100000},
#         {'name': 'Purdue Boilermakers', 'price': 100000},
#         {'name': 'Memphis Tigers', 'price': 100000},
#         {'name': 'Indiana Hoosiers', 'price': 100000},
#         {'name': 'Mississippi State Bulldogs', 'price': 100000},
#         {'name': 'Cincinnati Bearcats', 'price': 100000},
#         {'name': 'Appalachian State Mountaineers', 'price': 100000},
#         {'name': 'Virginia Cavaliers', 'price': 100000},
#         {'name': 'Georgia Southern Eagles', 'price': 100000},
#         {'name': 'South Alabama Jaguars', 'price': 100000},
#         {'name': 'Georgia State Panthers', 'price': 100000},
#         {'name': 'Minnesota Golden Gophers', 'price': 100000},
#         {'name': 'Illinois Fighting Illini', 'price': 100000},
#         {'name': 'San Diego State Aztecs', 'price': 200000},
#         {'name': 'Buffalo Bulls', 'price': 200000},
#         {'name': 'Miami (OH) RedHawks', 'price': 200000},
#         {'name': 'Texas State Bobcats', 'price': 200000},
#         {'name': 'Ohio Bobcats', 'price': 200000},
#         {'name': 'Stanford Cardinal', 'price': 200000},
#         {'name': 'Toledo Rockets', 'price': 200000},
#         {'name': 'North Texas Mean Green', 'price': 200000},
#         {'name': 'UAB Blazers', 'price': 200000},
#         {'name': 'Florida Atlantic Owls', 'price': 200000},
#         {'name': 'Bowling Green Falcons', 'price': 200000},
#         {'name': 'Charlotte 49ers', 'price': 200000},
#         {'name': 'Louisiana Ragin Cajuns', 'price': 200000},
#         {'name': 'New Mexico State Aggies', 'price': 500000},
#         {'name': 'Nevada Wolf Pack', 'price': 500000},
#         {'name': 'Tulsa Golden Hurricane', 'price': 500000},
#         {'name': 'Hawaii Rainbow Warriors', 'price': 500000},
#         {'name': 'Navy Midshipmen', 'price': 500000},
#         {'name': 'Army Black Knights', 'price': 500000},
#         {'name': 'Arkansas State Red Wolves', 'price': 500000},
#         {'name': 'South Florida Bulls', 'price': 500000},
#         {'name': 'Wyoming Cowboys', 'price': 500000},
#         {'name': 'Eastern Michigan Eagles', 'price': 500000},
#         {'name': 'Northern Illinois Huskies', 'price': 500000},
#         {'name': 'Middle Tennessee Blue Raiders', 'price': 500000},
#         {'name': 'Louisiana Tech Bulldogs', 'price': 500000},
#         {'name': 'Akron Zips', 'price': 500000},
#         {'name': 'Vanderbilt Commodores', 'price': 500000},
#         {'name': 'Western Michigan Broncos', 'price': 500000},
#         {'name': 'Western Kentucky Hilltoppers', 'price': 500000},
#         {'name': 'Marshall Thundering Herd', 'price': 500000},
#         {'name': 'Old Dominion Monarchs', 'price': 500000},
#         {'name': 'Rice Owls', 'price': 500000},
#         {'name': 'Temple Owls', 'price': 500000},
#         {'name': 'Central Michigan Chippewas', 'price': 500000},
#         {'name': 'New Mexico Lobos', 'price': 500000},
#         {'name': 'Southern Mississippi Golden Eagles', 'price': 500000},
#         {'name': 'UTEP Miners', 'price': 500000}]}]},
#     {'key': 'draftkings',
#      'title': 'DraftKings',
#      'last_update': '2024-02-17T09:13:14Z',
#      'markets': [{'key': 'outrights',
#        'last_update': '2024-02-17T09:13:14Z',
#        'outcomes': [{'name': 'Georgia Bulldogs', 'price': 330},
#         {'name': 'Ohio State Buckeyes', 'price': 475},
#         {'name': 'Texas Longhorns', 'price': 750},
#         {'name': 'Alabama Crimson Tide', 'price': 1200},
#         {'name': 'Oregon Ducks', 'price': 1200},
#         {'name': 'LSU Tigers', 'price': 1200},
#         {'name': 'Michigan Wolverines', 'price': 1400},
#         {'name': 'Ole Miss Rebels', 'price': 1500},
#         {'name': 'Florida State Seminoles', 'price': 2000},
#         {'name': 'Clemson Tigers', 'price': 2200},
#         {'name': 'Penn State Nittany Lions', 'price': 2500},
#         {'name': 'Notre Dame Fighting Irish', 'price': 2800},
#         {'name': 'Missouri Tigers', 'price': 3000},
#         {'name': 'Texas A&M Aggies', 'price': 3500},
#         {'name': 'Tennessee Volunteers', 'price': 3500},
#         {'name': 'USC Trojans', 'price': 4000},
#         {'name': 'Oklahoma Sooners', 'price': 4000},
#         {'name': 'Utah Utes', 'price': 6000},
#         {'name': 'Washington Huskies', 'price': 7000},
#         {'name': 'Miami Hurricanes', 'price': 7000},
#         {'name': 'Kansas State Wildcats', 'price': 7000},
#         {'name': 'Arizona Wildcats', 'price': 8000},
#         {'name': 'Wisconsin Badgers', 'price': 10000},
#         {'name': 'Auburn Tigers', 'price': 10000},
#         {'name': 'Louisville Cardinals', 'price': 10000},
#         {'name': 'Florida Gators', 'price': 15000},
#         {'name': 'Texas Tech Red Raiders', 'price': 15000},
#         {'name': 'TCU Horned Frogs', 'price': 15000},
#         {'name': 'Oklahoma State Cowboys', 'price': 15000},
#         {'name': 'NC State Wolfpack', 'price': 15000},
#         {'name': 'North Carolina Tar Heels', 'price': 15000},
#         {'name': 'Kansas Jayhawks', 'price': 15000},
#         {'name': 'Colorado Buffaloes', 'price': 20000},
#         {'name': 'UCLA Bruins', 'price': 20000},
#         {'name': 'UCF Knights', 'price': 20000},
#         {'name': 'SMU Mustangs', 'price': 20000},
#         {'name': 'Nebraska Cornhuskers', 'price': 20000},
#         {'name': 'Iowa State Cyclones', 'price': 20000},
#         {'name': 'Iowa Hawkeyes', 'price': 20000},
#         {'name': 'Boise State Broncos', 'price': 30000},
#         {'name': 'Arkansas Razorbacks', 'price': 30000},
#         {'name': 'Michigan State Spartans', 'price': 30000},
#         {'name': 'Kentucky Wildcats', 'price': 30000},
#         {'name': 'West Virginia Mountaineers', 'price': 40000},
#         {'name': 'Virginia Tech Hokies', 'price': 40000},
#         {'name': 'South Carolina Gamecocks', 'price': 40000},
#         {'name': 'Maryland Terrapins', 'price': 40000},
#         {'name': 'UTSA Roadrunners', 'price': 50000},
#         {'name': 'California Golden Bears', 'price': 50000},
#         {'name': 'Baylor Bears', 'price': 50000},
#         {'name': 'Tulane Green Wave', 'price': 50000},
#         {'name': 'Arizona State Sun Devils', 'price': 50000},
#         {'name': 'Oregon State Beavers', 'price': 50000},
#         {'name': 'Mississippi State Bulldogs', 'price': 50000},
#         {'name': 'Minnesota Golden Gophers', 'price': 50000},
#         {'name': 'Liberty Flames', 'price': 50000},
#         {'name': 'James Madison Dukes', 'price': 50000},
#         {'name': 'Georgia Tech Yellow Jackets', 'price': 50000},
#         {'name': 'BYU Cougars', 'price': 60000},
#         {'name': 'Troy Trojans', 'price': 60000},
#         {'name': 'Illinois Fighting Illini', 'price': 60000},
#         {'name': 'Cincinnati Bearcats', 'price': 70000},
#         {'name': 'Syracuse Orange', 'price': 70000},
#         {'name': 'Fresno State Bulldogs', 'price': 70000},
#         {'name': 'Duke Blue Devils', 'price': 80000},
#         {'name': 'Washington State Cougars', 'price': 80000},
#         {'name': 'Coastal Carolina Chanticleers', 'price': 80000},
#         {'name': 'Wake Forest Demon Deacons', 'price': 80000},
#         {'name': 'Boston College Eagles', 'price': 80000},
#         {'name': 'UNLV Rebels', 'price': 80000},
#         {'name': 'Toledo Rockets', 'price': 80000},
#         {'name': 'Air Force Falcons', 'price': 80000},
#         {'name': 'San Jose State Spartans', 'price': 80000},
#         {'name': 'Pittsburgh Panthers', 'price': 80000},
#         {'name': 'Houston Cougars', 'price': 80000},
#         {'name': 'Wyoming Cowboys', 'price': 100000},
#         {'name': 'Western Kentucky Hilltoppers', 'price': 100000},
#         {'name': 'Virginia Cavaliers', 'price': 100000},
#         {'name': 'Appalachian State Mountaineers', 'price': 100000},
#         {'name': 'Stanford Cardinal', 'price': 100000},
#         {'name': 'South Florida Bulls', 'price': 100000},
#         {'name': 'South Alabama Jaguars', 'price': 100000},
#         {'name': 'Northwestern Wildcats', 'price': 100000},
#         {'name': 'Memphis Tigers', 'price': 100000},
#         {'name': 'Florida Atlantic Owls', 'price': 200000},
#         {'name': 'Colorado State Rams', 'price': 200000},
#         {'name': 'Vanderbilt Commodores', 'price': 200000},
#         {'name': 'Utah State Aggies', 'price': 200000},
#         {'name': 'UAB Blazers', 'price': 200000},
#         {'name': 'Texas State Bobcats', 'price': 200000},
#         {'name': 'San Diego State Aztecs', 'price': 200000},
#         {'name': 'Old Dominion Monarchs', 'price': 200000},
#         {'name': 'Ohio Bobcats', 'price': 200000},
#         {'name': 'New Mexico State Aggies', 'price': 200000},
#         {'name': 'Navy Midshipmen', 'price': 200000},
#         {'name': 'Miami (OH) RedHawks', 'price': 200000},
#         {'name': 'Marshall Thundering Herd', 'price': 200000},
#         {'name': 'Indiana Hoosiers', 'price': 200000},
#         {'name': 'Georgia State Panthers', 'price': 200000},
#         {'name': 'Georgia Southern Eagles', 'price': 200000},
#         {'name': 'East Carolina Pirates', 'price': 300000},
#         {'name': 'Bowling Green Falcons', 'price': 300000},
#         {'name': 'Army Black Knights', 'price': 300000},
#         {'name': 'North Texas Mean Green', 'price': 300000},
#         {'name': 'Nevada Wolf Pack', 'price': 300000},
#         {'name': 'Louisiana Ragin Cajuns', 'price': 300000},
#         {'name': 'Florida International Panthers', 'price': 500000},
#         {'name': 'Eastern Michigan Eagles', 'price': 500000},
#         {'name': 'Western Michigan Broncos', 'price': 500000},
#         {'name': 'Charlotte 49ers', 'price': 500000},
#         {'name': 'Central Michigan Chippewas', 'price': 500000},
#         {'name': 'UTEP Miners', 'price': 500000},
#         {'name': 'Buffalo Bulls', 'price': 500000},
#         {'name': 'Ball State Cardinals', 'price': 500000},
#         {'name': 'Arkansas State Red Wolves', 'price': 500000},
#         {'name': 'Tulsa Golden Hurricane', 'price': 500000},
#         {'name': 'Temple Owls', 'price': 500000},
#         {'name': 'Southern Mississippi Golden Eagles', 'price': 500000},
#         {'name': 'Rice Owls', 'price': 500000},
#         {'name': 'Northern Illinois Huskies', 'price': 500000},
#         {'name': 'New Mexico Lobos', 'price': 500000},
#         {'name': 'Middle Tennessee Blue Raiders', 'price': 500000},
#         {'name': 'Louisiana Tech Bulldogs', 'price': 500000},
#         {'name': 'Hawaii Rainbow Warriors', 'price': 500000}]}]},
#     {'key': 'betmgm',
#      'title': 'BetMGM',
#      'last_update': '2024-02-17T09:12:35Z',
#      'markets': [{'key': 'outrights',
#        'last_update': '2024-02-17T09:12:35Z',
#        'outcomes': [{'name': 'Georgia Bulldogs', 'price': 350},
#         {'name': 'Ohio State Buckeyes', 'price': 500},
#         {'name': 'Texas Longhorns', 'price': 750},
#         {'name': 'Alabama Crimson Tide', 'price': 800},
#         {'name': 'Oregon Ducks', 'price': 1000},
#         {'name': 'Michigan Wolverines', 'price': 1100},
#         {'name': 'Ole Miss Rebels', 'price': 1100},
#         {'name': 'LSU Tigers', 'price': 1600},
#         {'name': 'Clemson Tigers', 'price': 2000},
#         {'name': 'Florida State Seminoles', 'price': 2000},
#         {'name': 'Penn State Nittany Lions', 'price': 2500},
#         {'name': 'Notre Dame Fighting Irish', 'price': 2500},
#         {'name': 'Oklahoma Sooners', 'price': 3500},
#         {'name': 'USC Trojans', 'price': 3500},
#         {'name': 'Missouri Tigers', 'price': 3500},
#         {'name': 'Miami Hurricanes', 'price': 3500},
#         {'name': 'Texas A&M Aggies', 'price': 4000},
#         {'name': 'Tennessee Volunteers', 'price': 5000},
#         {'name': 'Washington Huskies', 'price': 8000},
#         {'name': 'Utah Utes', 'price': 8000},
#         {'name': 'Louisville Cardinals', 'price': 10000},
#         {'name': 'Wisconsin Badgers', 'price': 10000},
#         {'name': 'Auburn Tigers', 'price': 10000},
#         {'name': 'Kansas State Wildcats', 'price': 10000},
#         {'name': 'Colorado Buffaloes', 'price': 10000},
#         {'name': 'Arizona Wildcats', 'price': 12500},
#         {'name': 'North Carolina Tar Heels', 'price': 15000},
#         {'name': 'Florida Gators', 'price': 15000},
#         {'name': 'Kansas Jayhawks', 'price': 15000},
#         {'name': 'TCU Horned Frogs', 'price': 15000},
#         {'name': 'UCLA Bruins', 'price': 15000},
#         {'name': 'Iowa Hawkeyes', 'price': 20000},
#         {'name': 'Iowa State Cyclones', 'price': 20000},
#         {'name': 'NC State Wolfpack', 'price': 20000},
#         {'name': 'Nebraska Cornhuskers', 'price': 20000},
#         {'name': 'Texas Tech Red Raiders', 'price': 20000},
#         {'name': 'West Virginia Mountaineers', 'price': 20000},
#         {'name': 'Arkansas Razorbacks', 'price': 30000},
#         {'name': 'Kentucky Wildcats', 'price': 30000},
#         {'name': 'Michigan State Spartans', 'price': 30000},
#         {'name': 'Minnesota Golden Gophers', 'price': 30000},
#         {'name': 'Oregon State Beavers', 'price': 30000},
#         {'name': 'Purdue Boilermakers', 'price': 30000},
#         {'name': 'South Carolina Gamecocks', 'price': 30000},
#         {'name': 'UCF Knights', 'price': 30000},
#         {'name': 'Wake Forest Demon Deacons', 'price': 30000},
#         {'name': 'Baylor Bears', 'price': 50000},
#         {'name': 'Cincinnati Bearcats', 'price': 50000},
#         {'name': 'Houston Cougars', 'price': 50000},
#         {'name': 'Indiana Hoosiers', 'price': 50000},
#         {'name': 'Mississippi State Bulldogs', 'price': 50000},
#         {'name': 'Tulane Green Wave', 'price': 50000}]}]},
#     {'key': 'betrivers',
#      'title': 'BetRivers',
#      'last_update': '2024-02-17T09:13:45Z',
#      'markets': [{'key': 'outrights',
#        'last_update': '2024-02-17T09:13:45Z',
#        'outcomes': [{'name': 'Georgia Bulldogs', 'price': 350},
#         {'name': 'Ohio State Buckeyes', 'price': 550},
#         {'name': 'Texas Longhorns', 'price': 800},
#         {'name': 'Oregon Ducks', 'price': 850},
#         {'name': 'Alabama Crimson Tide', 'price': 1100},
#         {'name': 'Ole Miss Rebels', 'price': 1100},
#         {'name': 'Notre Dame Fighting Irish', 'price': 1400},
#         {'name': 'LSU Tigers', 'price': 1400},
#         {'name': 'Michigan Wolverines', 'price': 1600},
#         {'name': 'Penn State Nittany Lions', 'price': 2000},
#         {'name': 'Clemson Tigers', 'price': 2000},
#         {'name': 'Florida State Seminoles', 'price': 2500},
#         {'name': 'USC Trojans', 'price': 3000},
#         {'name': 'Tennessee Volunteers', 'price': 3000},
#         {'name': 'Texas A&M Aggies', 'price': 3000},
#         {'name': 'Missouri Tigers', 'price': 4000},
#         {'name': 'Oklahoma Sooners', 'price': 4500},
#         {'name': 'Auburn Tigers', 'price': 5000},
#         {'name': 'Washington Huskies', 'price': 5000},
#         {'name': 'Kansas State Wildcats', 'price': 6000},
#         {'name': 'Miami Hurricanes', 'price': 6000},
#         {'name': 'Utah Utes', 'price': 8000},
#         {'name': 'Louisville Cardinals', 'price': 10000},
#         {'name': 'Arizona Wildcats', 'price': 12000},
#         {'name': 'Wisconsin Badgers', 'price': 12000},
#         {'name': 'Florida Gators', 'price': 12000},
#         {'name': 'Texas Tech Red Raiders', 'price': 12000},
#         {'name': 'Arkansas Razorbacks', 'price': 15000},
#         {'name': 'Nebraska Cornhuskers', 'price': 15000},
#         {'name': 'North Carolina Tar Heels', 'price': 15000},
#         {'name': 'UCLA Bruins', 'price': 20000},
#         {'name': 'Kentucky Wildcats', 'price': 20000},
#         {'name': 'SMU Mustangs', 'price': 20000},
#         {'name': 'Colorado Buffaloes', 'price': 20000},
#         {'name': 'Kansas Jayhawks', 'price': 20000},
#         {'name': 'Oklahoma State Cowboys', 'price': 25000},
#         {'name': 'NC State Wolfpack', 'price': 25000},
#         {'name': 'South Carolina Gamecocks', 'price': 25000},
#         {'name': 'TCU Horned Frogs', 'price': 30000},
#         {'name': 'Michigan State Spartans', 'price': 30000},
#         {'name': 'UCF Knights', 'price': 40000},
#         {'name': 'Maryland Terrapins', 'price': 40000},
#         {'name': 'James Madison Dukes', 'price': 40000},
#         {'name': 'Iowa State Cyclones', 'price': 40000},
#         {'name': 'Virginia Tech Hokies', 'price': 40000},
#         {'name': 'Iowa Hawkeyes', 'price': 40000},
#         {'name': 'Cincinnati Bearcats', 'price': 50000},
#         {'name': 'Liberty Flames', 'price': 50000},
#         {'name': 'Mississippi State Bulldogs', 'price': 50000},
#         {'name': 'West Virginia Mountaineers', 'price': 50000},
#         {'name': 'Oregon State Beavers', 'price': 50000},
#         {'name': 'California Golden Bears', 'price': 50000},
#         {'name': 'Boise State Broncos', 'price': 60000},
#         {'name': 'Troy Trojans', 'price': 70000},
#         {'name': 'Baylor Bears', 'price': 70000},
#         {'name': 'Tulane Green Wave', 'price': 70000},
#         {'name': 'Pittsburgh Panthers', 'price': 80000},
#         {'name': 'Virginia Cavaliers', 'price': 80000},
#         {'name': 'Rutgers Scarlet Knights', 'price': 80000},
#         {'name': 'Memphis Tigers', 'price': 80000},
#         {'name': 'Minnesota Golden Gophers', 'price': 80000},
#         {'name': 'Vanderbilt Commodores', 'price': 80000},
#         {'name': 'Illinois Fighting Illini', 'price': 80000},
#         {'name': 'Arizona State Sun Devils', 'price': 80000},
#         {'name': 'Temple Owls', 'price': 80000},
#         {'name': 'Boston College Eagles', 'price': 80000},
#         {'name': 'Syracuse Orange', 'price': 80000},
#         {'name': 'Miami (OH) RedHawks', 'price': 80000},
#         {'name': 'Washington State Cougars', 'price': 80000},
#         {'name': 'San Diego State Aztecs', 'price': 100000},
#         {'name': 'Rice Owls', 'price': 100000},
#         {'name': 'East Carolina Pirates', 'price': 100000},
#         {'name': 'Purdue Boilermakers', 'price': 100000},
#         {'name': 'New Mexico State Aggies', 'price': 100000},
#         {'name': 'Coastal Carolina Chanticleers', 'price': 100000},
#         {'name': 'Louisiana Ragin Cajuns', 'price': 100000},
#         {'name': 'UMass Minutemen', 'price': 100000},
#         {'name': 'Houston Cougars', 'price': 100000},
#         {'name': 'Texas State Bobcats', 'price': 100000},
#         {'name': 'Charlotte 49ers', 'price': 100000},
#         {'name': 'UTSA Roadrunners', 'price': 100000},
#         {'name': 'South Alabama Jaguars', 'price': 100000},
#         {'name': 'Western Michigan Broncos', 'price': 100000},
#         {'name': 'UTEP Miners', 'price': 100000},
#         {'name': 'Fresno State Bulldogs', 'price': 100000},
#         {'name': 'Georgia Tech Yellow Jackets', 'price': 100000},
#         {'name': 'Georgia State Panthers', 'price': 100000},
#         {'name': 'Northwestern Wildcats', 'price': 100000},
#         {'name': 'Florida Atlantic Owls', 'price': 100000},
#         {'name': 'Western Kentucky Hilltoppers', 'price': 100000},
#         {'name': 'Ohio Bobcats', 'price': 100000},
#         {'name': 'Southern Mississippi Golden Eagles', 'price': 100000},
#         {'name': 'Central Michigan Chippewas', 'price': 100000},
#         {'name': 'BYU Cougars', 'price': 100000},
#         {'name': 'Buffalo Bulls', 'price': 100000},
#         {'name': 'Ball State Cardinals', 'price': 100000},
#         {'name': 'Toledo Rockets', 'price': 100000},
#         {'name': 'UL Monroe Warhawks', 'price': 100000},
#         {'name': 'Colorado State Rams', 'price': 100000},
#         {'name': 'Hawaii Rainbow Warriors', 'price': 100000},
#         {'name': 'Marshall Thundering Herd', 'price': 100000},
#         {'name': 'Wyoming Cowboys', 'price': 100000},
#         {'name': 'UAB Blazers', 'price': 100000},
#         {'name': 'UConn Huskies', 'price': 100000},
#         {'name': 'Wake Forest Demon Deacons', 'price': 100000},
#         {'name': 'Navy Midshipmen', 'price': 100000},
#         {'name': 'San Jose State Spartans', 'price': 100000},
#         {'name': 'Kent State Golden Flashes', 'price': 100000},
#         {'name': 'Eastern Michigan Eagles', 'price': 100000},
#         {'name': 'Arkansas State Red Wolves', 'price': 100000},
#         {'name': 'Indiana Hoosiers', 'price': 100000},
#         {'name': 'Nevada Wolf Pack', 'price': 100000},
#         {'name': 'North Texas Mean Green', 'price': 100000},
#         {'name': 'Air Force Falcons', 'price': 100000},
#         {'name': 'Army Black Knights', 'price': 100000},
#         {'name': 'Bowling Green Falcons', 'price': 100000},
#         {'name': 'Old Dominion Monarchs', 'price': 100000},
#         {'name': 'Utah State Aggies', 'price': 100000},
#         {'name': 'Duke Blue Devils', 'price': 100000},
#         {'name': 'UNLV Rebels', 'price': 100000},
#         {'name': 'Florida International Panthers', 'price': 100000},
#         {'name': 'Northern Illinois Huskies', 'price': 100000},
#         {'name': 'Akron Zips', 'price': 100000},
#         {'name': 'Georgia Southern Eagles', 'price': 100000},
#         {'name': 'New Mexico Lobos', 'price': 100000},
#         {'name': 'Middle Tennessee Blue Raiders', 'price': 100000},
#         {'name': 'Appalachian State Mountaineers', 'price': 100000},
#         {'name': 'Stanford Cardinal', 'price': 100000},
#         {'name': 'South Florida Bulls', 'price': 100000},
#         {'name': 'Louisiana Tech Bulldogs', 'price': 100000}]}]}]}],
# ...
#        'outcomes': [{'name': 'Montreal Impact', 'price': 420},
#         {'name': 'Orlando City SC', 'price': -155},
#         {'name': 'Draw', 'price': 300}]}]},
#     {'key': 'unibet_us',
#      'title': 'Unibet',
#      'last_update': '2024-02-17T09:14:21Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:14:21Z',
#        'outcomes': [{'name': 'Montreal Impact', 'price': 410},
#         {'name': 'Orlando City SC', 'price': -159},
#         {'name': 'Draw', 'price': 295}]}]},
#     {'key': 'superbook',
#      'title': 'SuperBook',
#      'last_update': '2024-02-17T09:13:17Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:17Z',
#        'outcomes': [{'name': 'Montreal Impact', 'price': 395},
#         {'name': 'Orlando City SC', 'price': -165},
#         {'name': 'Draw', 'price': 295}]}]},
#     {'key': 'draftkings',
#      'title': 'DraftKings',
#      'last_update': '2024-02-17T09:10:28Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:10:28Z',
#        'outcomes': [{'name': 'Montreal Impact', 'price': 390},
#         {'name': 'Orlando City SC', 'price': -170},
#         {'name': 'Draw', 'price': 290}]}]}]},
#   {'id': '647e3503b029b7debec1f57d02a0c7f8',
#    'sport_key': 'soccer_usa_mls',
#    'sport_title': 'MLS',
#    'commence_time': '2024-02-25T01:30:00Z',
#    'home_team': 'Austin FC',
#    'away_team': 'Minnesota United FC',
#    'bookmakers': [{'key': 'fanduel',
#      'title': 'FanDuel',
#      'last_update': '2024-02-17T09:13:55Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:55Z',
#        'outcomes': [{'name': 'Austin FC', 'price': 100},
#         {'name': 'Minnesota United FC', 'price': 220},
#         {'name': 'Draw', 'price': 270}]}]},
#     {'key': 'bovada',
#      'title': 'Bovada',
#      'last_update': '2024-02-17T09:13:17Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:17Z',
#        'outcomes': [{'name': 'Austin FC', 'price': 110},
#         {'name': 'Minnesota United FC', 'price': 230},
#         {'name': 'Draw', 'price': 270}]}]},
#     {'key': 'betmgm',
#      'title': 'BetMGM',
#      'last_update': '2024-02-17T09:13:39Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:39Z',
#        'outcomes': [{'name': 'Austin FC', 'price': 100},
#         {'name': 'Minnesota United FC', 'price': 220},
#         {'name': 'Draw', 'price': 280}]}]},
#     {'key': 'superbook',
#      'title': 'SuperBook',
#      'last_update': '2024-02-17T09:13:17Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:17Z',
#        'outcomes': [{'name': 'Austin FC', 'price': 105},
#         {'name': 'Minnesota United FC', 'price': 220},
#         {'name': 'Draw', 'price': 255}]}]},
#     {'key': 'draftkings',
#      'title': 'DraftKings',
#      'last_update': '2024-02-17T09:10:28Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:10:28Z',
#        'outcomes': [{'name': 'Austin FC', 'price': 105},
#         {'name': 'Minnesota United FC', 'price': 210},
#         {'name': 'Draw', 'price': 265}]}]}]},
#   {'id': '37ed58be5c38ee2b5b5e9ba0d322a62c',
#    'sport_key': 'soccer_usa_mls',
#    'sport_title': 'MLS',
#    'commence_time': '2024-02-25T01:30:00Z',
#    'home_team': 'FC Dallas',
#    'away_team': 'San Jose Earthquakes',
#    'bookmakers': [{'key': 'fanduel',
#      'title': 'FanDuel',
#      'last_update': '2024-02-17T09:13:55Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:55Z',
#        'outcomes': [{'name': 'FC Dallas', 'price': -115},
#         {'name': 'San Jose Earthquakes', 'price': 300},
#         {'name': 'Draw', 'price': 240}]}]},
#     {'key': 'bovada',
#      'title': 'Bovada',
#      'last_update': '2024-02-17T09:13:17Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:17Z',
#        'outcomes': [{'name': 'FC Dallas', 'price': -105},
#         {'name': 'San Jose Earthquakes', 'price': 295},
#         {'name': 'Draw', 'price': 250}]}]},
#     {'key': 'betmgm',
#      'title': 'BetMGM',
#      'last_update': '2024-02-17T09:13:39Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:39Z',
#        'outcomes': [{'name': 'FC Dallas', 'price': -110},
#         {'name': 'San Jose Earthquakes', 'price': 270},
#         {'name': 'Draw', 'price': 260}]}]},
#     {'key': 'betrivers',
#      'title': 'BetRivers',
#      'last_update': '2024-02-17T09:13:17Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:17Z',
#        'outcomes': [{'name': 'FC Dallas', 'price': -108},
#         {'name': 'San Jose Earthquakes', 'price': 280},
#         {'name': 'Draw', 'price': 250}]}]},
#     {'key': 'unibet_us',
#      'title': 'Unibet',
#      'last_update': '2024-02-17T09:14:21Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:14:21Z',
#        'outcomes': [{'name': 'FC Dallas', 'price': -108},
#         {'name': 'San Jose Earthquakes', 'price': 280},
#         {'name': 'Draw', 'price': 250}]}]},
#     {'key': 'superbook',
#      'title': 'SuperBook',
#      'last_update': '2024-02-17T09:13:17Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:17Z',
#        'outcomes': [{'name': 'FC Dallas', 'price': -105},
#         {'name': 'San Jose Earthquakes', 'price': 265},
#         {'name': 'Draw', 'price': 245}]}]},
#     {'key': 'draftkings',
#      'title': 'DraftKings',
#      'last_update': '2024-02-17T09:10:28Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:10:28Z',
#        'outcomes': [{'name': 'FC Dallas', 'price': -110},
#         {'name': 'San Jose Earthquakes', 'price': 270},
#         {'name': 'Draw', 'price': 235}]}]}]},
#   {'id': 'a43e75d7a6ca5a9678377b53eb8af489',
#    'sport_key': 'soccer_usa_mls',
#    'sport_title': 'MLS',
#    'commence_time': '2024-02-25T01:30:00Z',
#    'home_team': 'Houston Dynamo',
#    'away_team': 'Sporting Kansas City',
#    'bookmakers': [{'key': 'bovada',
#      'title': 'Bovada',
#      'last_update': '2024-02-17T09:13:17Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:17Z',
#        'outcomes': [{'name': 'Houston Dynamo', 'price': -115},
#         {'name': 'Sporting Kansas City', 'price': 320},
#         {'name': 'Draw', 'price': 260}]}]},
#     {'key': 'fanduel',
#      'title': 'FanDuel',
#      'last_update': '2024-02-17T09:13:55Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:55Z',
#        'outcomes': [{'name': 'Houston Dynamo', 'price': -120},
#         {'name': 'Sporting Kansas City', 'price': 310},
#         {'name': 'Draw', 'price': 250}]}]},
#     {'key': 'betmgm',
#      'title': 'BetMGM',
#      'last_update': '2024-02-17T09:13:39Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:39Z',
#        'outcomes': [{'name': 'Houston Dynamo', 'price': -120},
#         {'name': 'Sporting Kansas City', 'price': 300},
#         {'name': 'Draw', 'price': 260}]}]},
#     {'key': 'superbook',
#      'title': 'SuperBook',
#      'last_update': '2024-02-17T09:13:17Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:17Z',
#        'outcomes': [{'name': 'Houston Dynamo', 'price': -125},
#         {'name': 'Sporting Kansas City', 'price': 300},
#         {'name': 'Draw', 'price': 260}]}]}]},
#   {'id': 'c700f328ea36cf85530eda8a54af9e2c',
#    'sport_key': 'soccer_usa_mls',
#    'sport_title': 'MLS',
#    'commence_time': '2024-02-25T01:30:00Z',
#    'home_team': 'St. Louis City SC',
#    'away_team': 'Real Salt Lake',
#    'bookmakers': [{'key': 'fanduel',
#      'title': 'FanDuel',
#      'last_update': '2024-02-17T09:13:55Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:55Z',
#        'outcomes': [{'name': 'Real Salt Lake', 'price': 220},
#         {'name': 'St. Louis City SC', 'price': 105},
#         {'name': 'Draw', 'price': 250}]}]},
#     {'key': 'unibet_us',
#      'title': 'Unibet',
#      'last_update': '2024-02-17T09:14:21Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:14:21Z',
#        'outcomes': [{'name': 'Real Salt Lake', 'price': 220},
#         {'name': 'St. Louis City SC', 'price': 108},
#         {'name': 'Draw', 'price': 270}]}]},
#     {'key': 'betrivers',
#      'title': 'BetRivers',
#      'last_update': '2024-02-17T09:13:17Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:17Z',
#        'outcomes': [{'name': 'Real Salt Lake', 'price': 220},
#         {'name': 'St. Louis City SC', 'price': 108},
#         {'name': 'Draw', 'price': 270}]}]},
#     {'key': 'superbook',
#      'title': 'SuperBook',
#      'last_update': '2024-02-17T09:13:17Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:17Z',
#        'outcomes': [{'name': 'Real Salt Lake', 'price': 220},
#         {'name': 'St. Louis City SC', 'price': 105},
#         {'name': 'Draw', 'price': 255}]}]},
#     {'key': 'betmgm',
#      'title': 'BetMGM',
#      'last_update': '2024-02-17T09:13:39Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:39Z',
#        'outcomes': [{'name': 'Real Salt Lake', 'price': 210},
#         {'name': 'St. Louis City SC', 'price': 110},
#         {'name': 'Draw', 'price': 260}]}]}]},
#   {'id': '57cd646b0c7fb5c76124bdd448a94262',
#    'sport_key': 'soccer_usa_mls',
#    'sport_title': 'MLS',
#    'commence_time': '2024-02-25T03:30:00Z',
#    'home_team': 'Portland Timbers',
#    'away_team': 'Colorado Rapids',
#    'bookmakers': [{'key': 'bovada',
#      'title': 'Bovada',
#      'last_update': '2024-02-17T09:13:17Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:17Z',
#        'outcomes': [{'name': 'Colorado Rapids', 'price': 400},
#         {'name': 'Portland Timbers', 'price': -155},
#         {'name': 'Draw', 'price': 310}]}]},
#     {'key': 'fanduel',
#      'title': 'FanDuel',
#      'last_update': '2024-02-17T09:13:55Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:55Z',
#        'outcomes': [{'name': 'Colorado Rapids', 'price': 400},
#         {'name': 'Portland Timbers', 'price': -165},
#         {'name': 'Draw', 'price': 300}]}]},
#     {'key': 'betmgm',
#      'title': 'BetMGM',
#      'last_update': '2024-02-17T09:13:39Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:39Z',
#        'outcomes': [{'name': 'Colorado Rapids', 'price': 360},
#         {'name': 'Portland Timbers', 'price': -160},
#         {'name': 'Draw', 'price': 320}]}]},
#     {'key': 'betrivers',
#      'title': 'BetRivers',
#      'last_update': '2024-02-17T09:13:17Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:17Z',
#        'outcomes': [{'name': 'Colorado Rapids', 'price': 370},
#         {'name': 'Portland Timbers', 'price': -150},
#         {'name': 'Draw', 'price': 300}]}]},
#     {'key': 'unibet_us',
#      'title': 'Unibet',
#      'last_update': '2024-02-17T09:14:21Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:14:21Z',
#        'outcomes': [{'name': 'Colorado Rapids', 'price': 370},
#         {'name': 'Portland Timbers', 'price': -150},
#         {'name': 'Draw', 'price': 300}]}]},
#     {'key': 'superbook',
#      'title': 'SuperBook',
#      'last_update': '2024-02-17T09:13:17Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:17Z',
#        'outcomes': [{'name': 'Colorado Rapids', 'price': 360},
#         {'name': 'Portland Timbers', 'price': -155},
#         {'name': 'Draw', 'price': 295}]}]},
#     {'key': 'draftkings',
#      'title': 'DraftKings',
#      'last_update': '2024-02-17T09:10:28Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:10:28Z',
#        'outcomes': [{'name': 'Colorado Rapids', 'price': 350},
#         {'name': 'Portland Timbers', 'price': -155},
#         {'name': 'Draw', 'price': 295}]}]}]},
#   {'id': 'daaa5765183771a2c48f5109eea9eba1',
#    'sport_key': 'soccer_usa_mls',
#    'sport_title': 'MLS',
#    'commence_time': '2024-02-25T19:30:00Z',
#    'home_team': 'FC Cincinnati',
#    'away_team': 'Toronto FC',
#    'bookmakers': [{'key': 'fanduel',
#      'title': 'FanDuel',
#      'last_update': '2024-02-17T09:13:55Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:55Z',
#        'outcomes': [{'name': 'FC Cincinnati', 'price': -320},
#         {'name': 'Toronto FC', 'price': 800},
#         {'name': 'Draw', 'price': 420}]}]},
#     {'key': 'bovada',
#      'title': 'Bovada',
#      'last_update': '2024-02-17T09:13:17Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:17Z',
#        'outcomes': [{'name': 'FC Cincinnati', 'price': -280},
#         {'name': 'Toronto FC', 'price': 700},
#         {'name': 'Draw', 'price': 440}]}]},
#     {'key': 'betmgm',
#      'title': 'BetMGM',
#      'last_update': '2024-02-17T09:13:39Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:39Z',
#        'outcomes': [{'name': 'FC Cincinnati', 'price': -300},
#         {'name': 'Toronto FC', 'price': 675},
#         {'name': 'Draw', 'price': 425}]}]},
#     {'key': 'betrivers',
#      'title': 'BetRivers',
#      'last_update': '2024-02-17T09:13:17Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:17Z',
#        'outcomes': [{'name': 'FC Cincinnati', 'price': -286},
#         {'name': 'Toronto FC', 'price': 700},
#         {'name': 'Draw', 'price': 410}]}]},
#     {'key': 'unibet_us',
#      'title': 'Unibet',
#      'last_update': '2024-02-17T09:14:21Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:14:21Z',
#        'outcomes': [{'name': 'FC Cincinnati', 'price': -286},
#         {'name': 'Toronto FC', 'price': 700},
#         {'name': 'Draw', 'price': 410}]}]},
#     {'key': 'draftkings',
#      'title': 'DraftKings',
#      'last_update': '2024-02-17T09:10:28Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:10:28Z',
#        'outcomes': [{'name': 'FC Cincinnati', 'price': -320},
#         {'name': 'Toronto FC', 'price': 600},
#         {'name': 'Draw', 'price': 425}]}]}]},
#   {'id': 'b38826d8d781da7fa51b700f6c5d28eb',
#    'sport_key': 'soccer_usa_mls',
#    'sport_title': 'MLS',
#    'commence_time': '2024-02-25T22:00:00Z',
#    'home_team': 'Nashville SC',
#    'away_team': 'New York Red Bulls',
#    'bookmakers': [{'key': 'fanduel',
#      'title': 'FanDuel',
#      'last_update': '2024-02-17T09:13:55Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:55Z',
#        'outcomes': [{'name': 'Nashville SC', 'price': 140},
#         {'name': 'New York Red Bulls', 'price': 200},
#         {'name': 'Draw', 'price': 200}]}]},
#     {'key': 'bovada',
#      'title': 'Bovada',
#      'last_update': '2024-02-17T09:13:17Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:17Z',
#        'outcomes': [{'name': 'Nashville SC', 'price': 140},
#         {'name': 'New York Red Bulls', 'price': 210},
#         {'name': 'Draw', 'price': 220}]}]},
#     {'key': 'betmgm',
#      'title': 'BetMGM',
#      'last_update': '2024-02-17T09:13:39Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:39Z',
#        'outcomes': [{'name': 'Nashville SC', 'price': 138},
#         {'name': 'New York Red Bulls', 'price': 200},
#         {'name': 'Draw', 'price': 210}]}]},
#     {'key': 'betrivers',
#      'title': 'BetRivers',
#      'last_update': '2024-02-17T09:13:17Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:13:17Z',
#        'outcomes': [{'name': 'Nashville SC', 'price': 138},
#         {'name': 'New York Red Bulls', 'price': 210},
#         {'name': 'Draw', 'price': 215}]}]},
#     {'key': 'unibet_us',
#      'title': 'Unibet',
#      'last_update': '2024-02-17T09:14:21Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:14:21Z',
#        'outcomes': [{'name': 'Nashville SC', 'price': 138},
#         {'name': 'New York Red Bulls', 'price': 210},
#         {'name': 'Draw', 'price': 215}]}]},
#     {'key': 'draftkings',
#      'title': 'DraftKings',
#      'last_update': '2024-02-17T09:10:28Z',
#      'markets': [{'key': 'h2h',
#        'last_update': '2024-02-17T09:10:28Z',
#        'outcomes': [{'name': 'Nashville SC', 'price': 140},
#         {'name': 'New York Red Bulls', 'price': 190},
#         {'name': 'Draw', 'price': 200}]}]}]}]}

# %%
SPORT = "americanfootball_ncaaf_championship_winner"
ncaaf_champ_odds_response = requests.get(
    f'{HOST}/v4/sports/{SPORT}/odds',
    params={
        'api_key': api_key,
        'regions': REGIONS,
        'oddsFormat': ODDS_FORMAT,
        'dateFormat': DATE_FORMAT,
    }
)

ncaaf_champ_odds_response.json()
# Out:
# [{'id': 'be95dd8b58f4a0c6de52611048d644bc',
#   'has_outrights': True,
#   'sport_key': 'americanfootball_ncaaf_championship_winner',
#   'sport_title': 'NCAAF Championship Winner',
#   'commence_time': '2025-01-15T01:00:00Z',
#   'home_team': None,
#   'away_team': None,
#   'bookmakers': [{'key': 'betonlineag',
#     'title': 'BetOnline.ag',
#     'last_update': '2024-02-17T09:09:45Z',
#     'markets': [{'key': 'outrights',
#       'last_update': '2024-02-17T09:09:45Z',
#       'outcomes': [{'name': 'Georgia Bulldogs', 'price': 350},
#        {'name': 'Ohio State Buckeyes', 'price': 550},
#        {'name': 'Texas Longhorns', 'price': 700},
#        {'name': 'Oregon Ducks', 'price': 800},
#        {'name': 'Alabama Crimson Tide', 'price': 1100},
#        {'name': 'Ole Miss Rebels', 'price': 1400},
#        {'name': 'Michigan Wolverines', 'price': 1600},
#        {'name': 'LSU Tigers', 'price': 1600},
#        {'name': 'Florida State Seminoles', 'price': 2200},
#        {'name': 'Penn State Nittany Lions', 'price': 3300},
#        {'name': 'Notre Dame Fighting Irish', 'price': 3300},
#        {'name': 'Texas A&M Aggies', 'price': 3300},
#        {'name': 'Missouri Tigers', 'price': 3300},
#        {'name': 'Clemson Tigers', 'price': 3500},
#        {'name': 'Oklahoma Sooners', 'price': 3500},
#        {'name': 'Tennessee Volunteers', 'price': 3500},
#        {'name': 'USC Trojans', 'price': 4500},
#        {'name': 'Washington Huskies', 'price': 6000},
#        {'name': 'Kansas State Wildcats', 'price': 6600},
#        {'name': 'Miami Hurricanes', 'price': 6600},
#        {'name': 'Utah Utes', 'price': 7500},
#        {'name': 'Auburn Tigers', 'price': 10000},
#        {'name': 'Arizona Wildcats', 'price': 10000},
#        {'name': 'Louisville Cardinals', 'price': 15000},
#        {'name': 'Florida Gators', 'price': 15000},
#        {'name': 'Nebraska Cornhuskers', 'price': 15000},
#        {'name': 'Texas Tech Red Raiders', 'price': 20000},
#        {'name': 'Wisconsin Badgers', 'price': 20000},
#        {'name': 'Kansas Jayhawks', 'price': 20000},
#        {'name': 'Kentucky Wildcats', 'price': 20000},
#        {'name': 'Oklahoma State Cowboys', 'price': 20000},
#        {'name': 'SMU Mustangs', 'price': 20000},
#        {'name': 'Arkansas Razorbacks', 'price': 25000},
#        {'name': 'North Carolina Tar Heels', 'price': 25000},
#        {'name': 'Colorado Buffaloes', 'price': 25000},
#        {'name': 'South Carolina Gamecocks', 'price': 25000},
#        {'name': 'NC State Wolfpack', 'price': 25000},
#        {'name': 'UCLA Bruins', 'price': 30000},
#        {'name': 'TCU Horned Frogs', 'price': 30000},
#        {'name': 'UCF Knights', 'price': 30000},
#        {'name': 'Iowa State Cyclones', 'price': 40000},
#        {'name': 'Maryland Terrapins', 'price': 40000},
#        {'name': 'Iowa Hawkeyes', 'price': 40000},
#        {'name': 'Michigan State Spartans', 'price': 50000},
#        {'name': 'James Madison Dukes', 'price': 50000},
#        {'name': 'Virginia Tech Hokies', 'price': 50000},
#        {'name': 'Oregon State Beavers', 'price': 50000},
#        {'name': 'West Virginia Mountaineers', 'price': 50000},
#        {'name': 'Liberty Flames', 'price': 50000},
#        {'name': 'California Golden Bears', 'price': 50000},
#        {'name': 'Mississippi State Bulldogs', 'price': 50000},
#        {'name': 'Boise State Broncos', 'price': 50000},
#        {'name': 'Cincinnati Bearcats', 'price': 60000},
#        {'name': 'Baylor Bears', 'price': 60000},
#        {'name': 'Tulane Green Wave', 'price': 75000},
#        {'name': 'Troy Trojans', 'price': 75000},
#        {'name': 'Virginia Cavaliers', 'price': 75000},
#        {'name': 'Boston College Eagles', 'price': 75000},
#        {'name': 'Arizona State Sun Devils', 'price': 75000},
#        {'name': 'Rutgers Scarlet Knights', 'price': 75000},
#        {'name': 'Pittsburgh Panthers', 'price': 100000},
#        {'name': 'Illinois Fighting Illini', 'price': 100000},
#        {'name': 'Minnesota Golden Gophers', 'price': 100000},
#        {'name': 'Sam Houston State Bearkats', 'price': 100000},
#        {'name': 'Kent State Golden Flashes', 'price': 100000},
#        {'name': 'Houston Cougars', 'price': 100000},
#        {'name': 'Colorado State Rams', 'price': 100000},
#        {'name': 'BYU Cougars', 'price': 100000},
#        {'name': 'Rice Owls', 'price': 100000},
#        {'name': 'Western Kentucky Hilltoppers', 'price': 100000},
#        {'name': 'Vanderbilt Commodores', 'price': 100000},
#        {'name': 'Wake Forest Demon Deacons', 'price': 100000},
#        {'name': 'Miami (OH) RedHawks', 'price': 100000},
#        {'name': 'Appalachian State Mountaineers', 'price': 100000},
#        {'name': 'Bowling Green Falcons', 'price': 100000},
#        {'name': 'East Carolina Pirates', 'price': 100000},
#        {'name': 'San Diego State Aztecs', 'price': 100000},
#        {'name': 'Arkansas State Red Wolves', 'price': 100000},
#        {'name': 'San Jose State Spartans', 'price': 100000},
#        {'name': 'Georgia Tech Yellow Jackets', 'price': 100000},
#        {'name': 'New Mexico Lobos', 'price': 100000},
#        {'name': 'Western Michigan Broncos', 'price': 100000},
#        {'name': 'Ball State Cardinals', 'price': 100000},
#        {'name': 'UL Monroe Warhawks', 'price': 100000},
#        {'name': 'Texas State Bobcats', 'price': 100000},
#        {'name': 'Memphis Tigers', 'price': 100000},
#        {'name': 'Eastern Michigan Eagles', 'price': 100000},
#        {'name': 'Louisiana Ragin Cajuns', 'price': 100000},
#        {'name': 'Duke Blue Devils', 'price': 100000},
#        {'name': 'Wyoming Cowboys', 'price': 100000},
#        {'name': 'UNLV Rebels', 'price': 100000},
#        {'name': 'Florida International Panthers', 'price': 100000},
#        {'name': 'Buffalo Bulls', 'price': 100000},
#        {'name': 'Stanford Cardinal', 'price': 100000},
#        {'name': 'Marshall Thundering Herd', 'price': 100000},
#        {'name': 'Ohio Bobcats', 'price': 100000},
#        {'name': 'South Alabama Jaguars', 'price': 100000},
#        {'name': 'Tulsa Golden Hurricane', 'price': 100000},
#        {'name': 'Army Black Knights', 'price': 100000},
#        {'name': 'Toledo Rockets', 'price': 100000},
#        {'name': 'Central Michigan Chippewas', 'price': 100000},
#        {'name': 'UTEP Miners', 'price': 100000},
#        {'name': 'Air Force Falcons', 'price': 100000},
#        {'name': 'UTSA Roadrunners', 'price': 100000},
#        {'name': 'Nevada Wolf Pack', 'price': 100000},
#        {'name': 'Coastal Carolina Chanticleers', 'price': 100000},
#        {'name': 'UAB Blazers', 'price': 100000},
#        {'name': 'UConn Huskies', 'price': 100000},
#        {'name': 'Florida Atlantic Owls', 'price': 100000},
#        {'name': 'Old Dominion Monarchs', 'price': 100000},
#        {'name': 'North Texas Mean Green', 'price': 100000},
#        {'name': 'UMass Minutemen', 'price': 100000},
#        {'name': 'Utah State Aggies', 'price': 100000},
#        {'name': 'Syracuse Orange', 'price': 100000},
#        {'name': 'Louisiana Tech Bulldogs', 'price': 100000},
#        {'name': 'Charlotte 49ers', 'price': 100000},
#        {'name': 'Southern Mississippi Golden Eagles', 'price': 100000},
#        {'name': 'Georgia State Panthers', 'price': 100000},
#        {'name': 'Fresno State Bulldogs', 'price': 100000},
#        {'name': 'Temple Owls', 'price': 100000},
#        {'name': 'Purdue Boilermakers', 'price': 100000},
#        {'name': 'Washington State Cougars', 'price': 100000},
#        {'name': 'Indiana Hoosiers', 'price': 100000},
#        {'name': 'Akron Zips', 'price': 100000},
#        {'name': 'Hawaii Rainbow Warriors', 'price': 100000},
#        {'name': 'South Florida Bulls', 'price': 100000},
#        {'name': 'Jacksonville State Gamecocks', 'price': 100000},
#        {'name': 'Middle Tennessee Blue Raiders', 'price': 100000},
#        {'name': 'Georgia Southern Eagles', 'price': 100000},
#        {'name': 'Northern Illinois Huskies', 'price': 100000}]}]},
#    {'key': 'fanduel',
#     'title': 'FanDuel',
#     'last_update': '2024-02-17T09:09:26Z',
#     'markets': [{'key': 'outrights',
#       'last_update': '2024-02-17T09:09:26Z',
#       'outcomes': [{'name': 'Georgia Bulldogs', 'price': 300},
#        {'name': 'Ohio State Buckeyes', 'price': 500},
#        {'name': 'Texas Longhorns', 'price': 700},
#        {'name': 'Oregon Ducks', 'price': 850},
#        {'name': 'Alabama Crimson Tide', 'price': 1200},
#        {'name': 'LSU Tigers', 'price': 1500},
#        {'name': 'Michigan Wolverines', 'price': 1500},
#        {'name': 'Ole Miss Rebels', 'price': 1500},
#        {'name': 'Florida State Seminoles', 'price': 2000},
#        {'name': 'Penn State Nittany Lions', 'price': 2500},
#        {'name': 'Notre Dame Fighting Irish', 'price': 2500},
#        {'name': 'Missouri Tigers', 'price': 3000},
#        {'name': 'Clemson Tigers', 'price': 3000},
#        {'name': 'Tennessee Volunteers', 'price': 3000},
#        {'name': 'Texas A&M Aggies', 'price': 4000},
#        {'name': 'USC Trojans', 'price': 4000},
#        {'name': 'Utah Utes', 'price': 6000},
#        {'name': 'Miami Hurricanes', 'price': 6000},
#        {'name': 'Oklahoma Sooners', 'price': 6000},
#        {'name': 'Kansas State Wildcats', 'price': 6000},
#        {'name': 'Auburn Tigers', 'price': 10000},
#        {'name': 'Washington Huskies', 'price': 10000},
#        {'name': 'Louisville Cardinals', 'price': 12000},
#        {'name': 'Arizona Wildcats', 'price': 15000},
#        {'name': 'Kansas Jayhawks', 'price': 20000},
#        {'name': 'Texas Tech Red Raiders', 'price': 20000},
#        {'name': 'Kentucky Wildcats', 'price': 20000},
#        {'name': 'Florida Gators', 'price': 20000},
#        {'name': 'SMU Mustangs', 'price': 20000},
#        {'name': 'North Carolina Tar Heels', 'price': 25000},
#        {'name': 'Wisconsin Badgers', 'price': 25000},
#        {'name': 'Arkansas Razorbacks', 'price': 25000},
#        {'name': 'Iowa Hawkeyes', 'price': 25000},
#        {'name': 'South Carolina Gamecocks', 'price': 25000},
#        {'name': 'NC State Wolfpack', 'price': 25000},
#        {'name': 'Nebraska Cornhuskers', 'price': 30000},
#        {'name': 'TCU Horned Frogs', 'price': 30000},
#        {'name': 'Iowa State Cyclones', 'price': 30000},
#        {'name': 'Colorado Buffaloes', 'price': 30000},
#        {'name': 'UCF Knights', 'price': 30000},
#        {'name': 'Oklahoma State Cowboys', 'price': 30000},
#        {'name': 'Maryland Terrapins', 'price': 40000},
#        {'name': 'Virginia Tech Hokies', 'price': 50000},
#        {'name': 'Oregon State Beavers', 'price': 50000},
#        {'name': 'West Virginia Mountaineers', 'price': 50000},
#        {'name': 'Michigan State Spartans', 'price': 50000},
#        {'name': 'Liberty Flames', 'price': 50000},
#        {'name': 'UCLA Bruins', 'price': 50000},
#        {'name': 'California Golden Bears', 'price': 50000},
#        {'name': 'Boise State Broncos', 'price': 50000},
#        {'name': 'Memphis Tigers', 'price': 60000},
#        {'name': 'Mississippi State Bulldogs', 'price': 60000},
#        {'name': 'James Madison Dukes', 'price': 60000},
#        {'name': 'Baylor Bears', 'price': 60000},
#        {'name': 'Arizona State Sun Devils', 'price': 80000},
#        {'name': 'Cincinnati Bearcats', 'price': 80000},
#        {'name': 'Virginia Cavaliers', 'price': 80000},
#        {'name': 'Tulane Green Wave', 'price': 80000},
#        {'name': 'Syracuse Orange', 'price': 80000},
#        {'name': 'Troy Trojans', 'price': 80000},
#        {'name': 'Sam Houston State Bearkats', 'price': 100000},
#        {'name': 'Kent State Golden Flashes', 'price': 100000},
#        {'name': 'Houston Cougars', 'price': 100000},
#        {'name': 'Colorado State Rams', 'price': 100000},
#        {'name': 'BYU Cougars', 'price': 100000},
#        {'name': 'Rice Owls', 'price': 100000},
#        {'name': 'Western Kentucky Hilltoppers', 'price': 100000},
#        {'name': 'Vanderbilt Commodores', 'price': 100000},
#        {'name': 'Wake Forest Demon Deacons', 'price': 100000},
#        {'name': 'Miami (OH) RedHawks', 'price': 100000},
#        {'name': 'Appalachian State Mountaineers', 'price': 100000},
#        {'name': 'Bowling Green Falcons', 'price': 100000},
#        {'name': 'East Carolina Pirates', 'price': 100000},
#        {'name': 'San Diego State Aztecs', 'price': 100000},
#        {'name': 'Arkansas State Red Wolves', 'price': 100000},
#        {'name': 'San Jose State Spartans', 'price': 100000},
#        {'name': 'Pittsburgh Panthers', 'price': 100000},
#        {'name': 'Georgia Tech Yellow Jackets', 'price': 100000},
#        {'name': 'New Mexico Lobos', 'price': 100000},
#        {'name': 'Western Michigan Broncos', 'price': 100000},
#        {'name': 'Ball State Cardinals', 'price': 100000},
#        {'name': 'UL Monroe Warhawks', 'price': 100000},
#        {'name': 'Texas State Bobcats', 'price': 100000},
#        {'name': 'Eastern Michigan Eagles', 'price': 100000},
#        {'name': 'Louisiana Ragin Cajuns', 'price': 100000},
#        {'name': 'Duke Blue Devils', 'price': 100000},
#        {'name': 'New Mexico State Aggies', 'price': 100000},
#        {'name': 'Navy Midshipmen', 'price': 100000},
#        {'name': 'Wyoming Cowboys', 'price': 100000},
#        {'name': 'UNLV Rebels', 'price': 100000},
#        {'name': 'Buffalo Bulls', 'price': 100000},
#        {'name': 'Stanford Cardinal', 'price': 100000},
#        {'name': 'Marshall Thundering Herd', 'price': 100000},
#        {'name': 'Northwestern Wildcats', 'price': 100000},
#        {'name': 'Ohio Bobcats', 'price': 100000},
#        {'name': 'Boston College Eagles', 'price': 100000},
#        {'name': 'South Alabama Jaguars', 'price': 100000},
#        {'name': 'Tulsa Golden Hurricane', 'price': 100000},
#        {'name': 'Army Black Knights', 'price': 100000},
#        {'name': 'Toledo Rockets', 'price': 100000},
#        {'name': 'Central Michigan Chippewas', 'price': 100000},
#        {'name': 'UTEP Miners', 'price': 100000},
#        {'name': 'Air Force Falcons', 'price': 100000},
#        {'name': 'UTSA Roadrunners', 'price': 100000},
#        {'name': 'Nevada Wolf Pack', 'price': 100000},
#        {'name': 'Coastal Carolina Chanticleers', 'price': 100000},
#        {'name': 'UAB Blazers', 'price': 100000},
#        {'name': 'UConn Huskies', 'price': 100000},
#        {'name': 'Florida Atlantic Owls', 'price': 100000},
#        {'name': 'Old Dominion Monarchs', 'price': 100000},
#        {'name': 'North Texas Mean Green', 'price': 100000},
#        {'name': 'UMass Minutemen', 'price': 100000},
#        {'name': 'Utah State Aggies', 'price': 100000},
#        {'name': 'Louisiana Tech Bulldogs', 'price': 100000},
#        {'name': 'Charlotte 49ers', 'price': 100000},
#        {'name': 'Illinois Fighting Illini', 'price': 100000},
#        {'name': 'Southern Mississippi Golden Eagles', 'price': 100000},
#        {'name': 'Georgia State Panthers', 'price': 100000},
#        {'name': 'Fresno State Bulldogs', 'price': 100000},
#        {'name': 'Temple Owls', 'price': 100000},
#        {'name': 'Purdue Boilermakers', 'price': 100000},
#        {'name': 'Washington State Cougars', 'price': 100000},
#        {'name': 'Indiana Hoosiers', 'price': 100000},
#        {'name': 'Minnesota Golden Gophers', 'price': 100000},
#        {'name': 'Akron Zips', 'price': 100000},
#        {'name': 'Hawaii Rainbow Warriors', 'price': 100000},
#        {'name': 'South Florida Bulls', 'price': 100000},
#        {'name': 'Jacksonville State Gamecocks', 'price': 100000},
#        {'name': 'Middle Tennessee Blue Raiders', 'price': 100000},
#        {'name': 'Georgia Southern Eagles', 'price': 100000},
#        {'name': 'Northern Illinois Huskies', 'price': 100000},
#        {'name': 'Florida International Panthers', 'price': 100000}]}]},
#    {'key': 'williamhill_us',
#     'title': 'Caesars',
#     'last_update': '2024-02-17T09:07:56Z',
#     'markets': [{'key': 'outrights',
#       'last_update': '2024-02-17T09:07:56Z',
#       'outcomes': [{'name': 'Georgia Bulldogs', 'price': 350},
#        {'name': 'Ohio State Buckeyes', 'price': 400},
#        {'name': 'Texas Longhorns', 'price': 800},
#        {'name': 'Oregon Ducks', 'price': 1000},
#        {'name': 'Alabama Crimson Tide', 'price': 1100},
#        {'name': 'LSU Tigers', 'price': 1300},
#        {'name': 'Ole Miss Rebels', 'price': 1400},
#        {'name': 'Michigan Wolverines', 'price': 1600},
#        {'name': 'Florida State Seminoles', 'price': 2000},
#        {'name': 'USC Trojans', 'price': 2200},
#        {'name': 'Notre Dame Fighting Irish', 'price': 2200},
#        {'name': 'Penn State Nittany Lions', 'price': 2500},
#        {'name': 'Clemson Tigers', 'price': 2800},
#        {'name': 'Tennessee Volunteers', 'price': 3500},
#        {'name': 'Oklahoma Sooners', 'price': 4000},
#        {'name': 'Missouri Tigers', 'price': 4000},
#        {'name': 'Texas A&M Aggies', 'price': 4000},
#        {'name': 'Kansas State Wildcats', 'price': 5000},
#        {'name': 'Arizona Wildcats', 'price': 5000},
#        {'name': 'Washington Huskies', 'price': 6000},
#        {'name': 'Miami Hurricanes', 'price': 6000},
#        {'name': 'Colorado Buffaloes', 'price': 7500},
#        {'name': 'Louisville Cardinals', 'price': 7500},
#        {'name': 'Utah Utes', 'price': 7500},
#        {'name': 'SMU Mustangs', 'price': 10000},
#        {'name': 'Auburn Tigers', 'price': 10000},
#        {'name': 'Nebraska Cornhuskers', 'price': 11000},
#        {'name': 'Kentucky Wildcats', 'price': 12500},
#        {'name': 'NC State Wolfpack', 'price': 12500},
#        {'name': 'Iowa Hawkeyes', 'price': 12500},
#        {'name': 'North Carolina Tar Heels', 'price': 12500},
#        {'name': 'Kansas Jayhawks', 'price': 12500},
#        {'name': 'Oklahoma State Cowboys', 'price': 12500},
#        {'name': 'Wisconsin Badgers', 'price': 15000},
#        {'name': 'UCLA Bruins', 'price': 20000},
#        {'name': 'Florida Gators', 'price': 20000},
#        {'name': 'Texas Tech Red Raiders', 'price': 20000},
#        {'name': 'UCF Knights', 'price': 20000},
#        {'name': 'Iowa State Cyclones', 'price': 25000},
#        {'name': 'Boise State Broncos', 'price': 25000},
#        {'name': 'Tulane Green Wave', 'price': 25000},
#        {'name': 'Michigan State Spartans', 'price': 25000},
#        {'name': 'Maryland Terrapins', 'price': 30000},
#        {'name': 'Virginia Tech Hokies', 'price': 30000},
#        {'name': 'South Carolina Gamecocks', 'price': 30000},
#        {'name': 'TCU Horned Frogs', 'price': 30000},
#        {'name': 'Liberty Flames', 'price': 30000},
#        {'name': 'Duke Blue Devils', 'price': 40000},
#        {'name': 'Boston College Eagles', 'price': 40000},
#        {'name': 'UTSA Roadrunners', 'price': 40000},
#        {'name': 'Georgia Tech Yellow Jackets', 'price': 40000},
#        {'name': 'Arizona State Sun Devils', 'price': 40000},
#        {'name': 'California Golden Bears', 'price': 50000},
#        {'name': 'Arkansas Razorbacks', 'price': 50000},
#        {'name': 'West Virginia Mountaineers', 'price': 50000},
#        {'name': 'Troy Trojans', 'price': 50000},
#        {'name': 'Oregon State Beavers', 'price': 75000},
#        {'name': 'James Madison Dukes', 'price': 75000},
#        {'name': 'Wake Forest Demon Deacons', 'price': 75000},
#        {'name': 'Baylor Bears', 'price': 75000},
#        {'name': 'Syracuse Orange', 'price': 75000},
#        {'name': 'San Jose State Spartans', 'price': 75000},
#        {'name': 'UNLV Rebels', 'price': 75000},
#        {'name': 'Washington State Cougars', 'price': 75000},
#        {'name': 'Air Force Falcons', 'price': 100000},
#        {'name': 'Fresno State Bulldogs', 'price': 100000},
#        {'name': 'Houston Cougars', 'price': 100000},
#        {'name': 'Northwestern Wildcats', 'price': 100000},
#        {'name': 'Pittsburgh Panthers', 'price': 100000},
#        {'name': 'Utah State Aggies', 'price': 100000},
#        {'name': 'Colorado State Rams', 'price': 100000},
#        {'name': 'BYU Cougars', 'price': 100000},
#        {'name': 'Coastal Carolina Chanticleers', 'price': 100000},
#        {'name': 'Purdue Boilermakers', 'price': 100000},
#        {'name': 'Memphis Tigers', 'price': 100000},
#        {'name': 'Indiana Hoosiers', 'price': 100000},
#        {'name': 'Mississippi State Bulldogs', 'price': 100000},
#        {'name': 'Cincinnati Bearcats', 'price': 100000},
#        {'name': 'Appalachian State Mountaineers', 'price': 100000},
#        {'name': 'Virginia Cavaliers', 'price': 100000},
#        {'name': 'Georgia Southern Eagles', 'price': 100000},
#        {'name': 'South Alabama Jaguars', 'price': 100000},
#        {'name': 'Georgia State Panthers', 'price': 100000},
#        {'name': 'Minnesota Golden Gophers', 'price': 100000},
#        {'name': 'Illinois Fighting Illini', 'price': 100000},
#        {'name': 'San Diego State Aztecs', 'price': 200000},
#        {'name': 'Buffalo Bulls', 'price': 200000},
#        {'name': 'Miami (OH) RedHawks', 'price': 200000},
#        {'name': 'Texas State Bobcats', 'price': 200000},
#        {'name': 'Ohio Bobcats', 'price': 200000},
#        {'name': 'Stanford Cardinal', 'price': 200000},
#        {'name': 'Toledo Rockets', 'price': 200000},
#        {'name': 'North Texas Mean Green', 'price': 200000},
#        {'name': 'UAB Blazers', 'price': 200000},
#        {'name': 'Florida Atlantic Owls', 'price': 200000},
#        {'name': 'Bowling Green Falcons', 'price': 200000},
#        {'name': 'Charlotte 49ers', 'price': 200000},
#        {'name': 'Louisiana Ragin Cajuns', 'price': 200000},
#        {'name': 'New Mexico State Aggies', 'price': 500000},
#        {'name': 'Nevada Wolf Pack', 'price': 500000},
#        {'name': 'Tulsa Golden Hurricane', 'price': 500000},
#        {'name': 'Hawaii Rainbow Warriors', 'price': 500000},
#        {'name': 'Navy Midshipmen', 'price': 500000},
#        {'name': 'Army Black Knights', 'price': 500000},
#        {'name': 'Arkansas State Red Wolves', 'price': 500000},
#        {'name': 'South Florida Bulls', 'price': 500000},
#        {'name': 'Wyoming Cowboys', 'price': 500000},
#        {'name': 'Eastern Michigan Eagles', 'price': 500000},
#        {'name': 'Northern Illinois Huskies', 'price': 500000},
#        {'name': 'Middle Tennessee Blue Raiders', 'price': 500000},
#        {'name': 'Louisiana Tech Bulldogs', 'price': 500000},
#        {'name': 'Akron Zips', 'price': 500000},
#        {'name': 'Vanderbilt Commodores', 'price': 500000},
#        {'name': 'Western Michigan Broncos', 'price': 500000},
#        {'name': 'Western Kentucky Hilltoppers', 'price': 500000},
#        {'name': 'Marshall Thundering Herd', 'price': 500000},
#        {'name': 'Old Dominion Monarchs', 'price': 500000},
#        {'name': 'Rice Owls', 'price': 500000},
#        {'name': 'Temple Owls', 'price': 500000},
#        {'name': 'Central Michigan Chippewas', 'price': 500000},
#        {'name': 'New Mexico Lobos', 'price': 500000},
#        {'name': 'Southern Mississippi Golden Eagles', 'price': 500000},
#        {'name': 'UTEP Miners', 'price': 500000}]}]},
#    {'key': 'draftkings',
#     'title': 'DraftKings',
#     'last_update': '2024-02-17T09:08:09Z',
#     'markets': [{'key': 'outrights',
#       'last_update': '2024-02-17T09:08:09Z',
#       'outcomes': [{'name': 'Georgia Bulldogs', 'price': 330},
#        {'name': 'Ohio State Buckeyes', 'price': 475},
#        {'name': 'Texas Longhorns', 'price': 750},
#        {'name': 'Alabama Crimson Tide', 'price': 1200},
#        {'name': 'Oregon Ducks', 'price': 1200},
#        {'name': 'LSU Tigers', 'price': 1200},
#        {'name': 'Michigan Wolverines', 'price': 1400},
#        {'name': 'Ole Miss Rebels', 'price': 1500},
#        {'name': 'Florida State Seminoles', 'price': 2000},
#        {'name': 'Clemson Tigers', 'price': 2200},
#        {'name': 'Penn State Nittany Lions', 'price': 2500},
#        {'name': 'Notre Dame Fighting Irish', 'price': 2800},
#        {'name': 'Missouri Tigers', 'price': 3000},
#        {'name': 'Texas A&M Aggies', 'price': 3500},
#        {'name': 'Tennessee Volunteers', 'price': 3500},
#        {'name': 'USC Trojans', 'price': 4000},
#        {'name': 'Oklahoma Sooners', 'price': 4000},
#        {'name': 'Utah Utes', 'price': 6000},
#        {'name': 'Washington Huskies', 'price': 7000},
#        {'name': 'Miami Hurricanes', 'price': 7000},
#        {'name': 'Kansas State Wildcats', 'price': 7000},
#        {'name': 'Arizona Wildcats', 'price': 8000},
#        {'name': 'Wisconsin Badgers', 'price': 10000},
#        {'name': 'Auburn Tigers', 'price': 10000},
#        {'name': 'Louisville Cardinals', 'price': 10000},
#        {'name': 'Florida Gators', 'price': 15000},
#        {'name': 'Texas Tech Red Raiders', 'price': 15000},
#        {'name': 'TCU Horned Frogs', 'price': 15000},
#        {'name': 'Oklahoma State Cowboys', 'price': 15000},
#        {'name': 'NC State Wolfpack', 'price': 15000},
#        {'name': 'North Carolina Tar Heels', 'price': 15000},
#        {'name': 'Kansas Jayhawks', 'price': 15000},
#        {'name': 'Colorado Buffaloes', 'price': 20000},
#        {'name': 'UCLA Bruins', 'price': 20000},
#        {'name': 'UCF Knights', 'price': 20000},
#        {'name': 'SMU Mustangs', 'price': 20000},
#        {'name': 'Nebraska Cornhuskers', 'price': 20000},
#        {'name': 'Iowa State Cyclones', 'price': 20000},
#        {'name': 'Iowa Hawkeyes', 'price': 20000},
#        {'name': 'Boise State Broncos', 'price': 30000},
#        {'name': 'Arkansas Razorbacks', 'price': 30000},
#        {'name': 'Michigan State Spartans', 'price': 30000},
#        {'name': 'Kentucky Wildcats', 'price': 30000},
#        {'name': 'West Virginia Mountaineers', 'price': 40000},
#        {'name': 'Virginia Tech Hokies', 'price': 40000},
#        {'name': 'South Carolina Gamecocks', 'price': 40000},
#        {'name': 'Maryland Terrapins', 'price': 40000},
#        {'name': 'California Golden Bears', 'price': 50000},
#        {'name': 'UTSA Roadrunners', 'price': 50000},
#        {'name': 'Baylor Bears', 'price': 50000},
#        {'name': 'Tulane Green Wave', 'price': 50000},
#        {'name': 'Arizona State Sun Devils', 'price': 50000},
#        {'name': 'Oregon State Beavers', 'price': 50000},
#        {'name': 'Mississippi State Bulldogs', 'price': 50000},
#        {'name': 'Minnesota Golden Gophers', 'price': 50000},
#        {'name': 'Liberty Flames', 'price': 50000},
#        {'name': 'James Madison Dukes', 'price': 50000},
#        {'name': 'Georgia Tech Yellow Jackets', 'price': 50000},
#        {'name': 'BYU Cougars', 'price': 60000},
#        {'name': 'Troy Trojans', 'price': 60000},
#        {'name': 'Illinois Fighting Illini', 'price': 60000},
#        {'name': 'Cincinnati Bearcats', 'price': 70000},
#        {'name': 'Syracuse Orange', 'price': 70000},
#        {'name': 'Fresno State Bulldogs', 'price': 70000},
#        {'name': 'Duke Blue Devils', 'price': 80000},
#        {'name': 'Washington State Cougars', 'price': 80000},
#        {'name': 'Coastal Carolina Chanticleers', 'price': 80000},
#        {'name': 'Wake Forest Demon Deacons', 'price': 80000},
#        {'name': 'Boston College Eagles', 'price': 80000},
#        {'name': 'UNLV Rebels', 'price': 80000},
#        {'name': 'Toledo Rockets', 'price': 80000},
#        {'name': 'Air Force Falcons', 'price': 80000},
#        {'name': 'San Jose State Spartans', 'price': 80000},
#        {'name': 'Pittsburgh Panthers', 'price': 80000},
#        {'name': 'Houston Cougars', 'price': 80000},
#        {'name': 'Wyoming Cowboys', 'price': 100000},
#        {'name': 'Western Kentucky Hilltoppers', 'price': 100000},
#        {'name': 'Virginia Cavaliers', 'price': 100000},
#        {'name': 'Appalachian State Mountaineers', 'price': 100000},
#        {'name': 'Stanford Cardinal', 'price': 100000},
#        {'name': 'South Florida Bulls', 'price': 100000},
#        {'name': 'South Alabama Jaguars', 'price': 100000},
#        {'name': 'Northwestern Wildcats', 'price': 100000},
#        {'name': 'Memphis Tigers', 'price': 100000},
#        {'name': 'Florida Atlantic Owls', 'price': 200000},
#        {'name': 'Colorado State Rams', 'price': 200000},
#        {'name': 'Vanderbilt Commodores', 'price': 200000},
#        {'name': 'Utah State Aggies', 'price': 200000},
#        {'name': 'UAB Blazers', 'price': 200000},
#        {'name': 'Texas State Bobcats', 'price': 200000},
#        {'name': 'San Diego State Aztecs', 'price': 200000},
#        {'name': 'Old Dominion Monarchs', 'price': 200000},
#        {'name': 'Ohio Bobcats', 'price': 200000},
#        {'name': 'New Mexico State Aggies', 'price': 200000},
#        {'name': 'Navy Midshipmen', 'price': 200000},
#        {'name': 'Miami (OH) RedHawks', 'price': 200000},
#        {'name': 'Marshall Thundering Herd', 'price': 200000},
#        {'name': 'Indiana Hoosiers', 'price': 200000},
#        {'name': 'Georgia State Panthers', 'price': 200000},
#        {'name': 'Georgia Southern Eagles', 'price': 200000},
#        {'name': 'East Carolina Pirates', 'price': 300000},
#        {'name': 'Bowling Green Falcons', 'price': 300000},
#        {'name': 'Army Black Knights', 'price': 300000},
#        {'name': 'North Texas Mean Green', 'price': 300000},
#        {'name': 'Nevada Wolf Pack', 'price': 300000},
#        {'name': 'Louisiana Ragin Cajuns', 'price': 300000},
#        {'name': 'Florida International Panthers', 'price': 500000},
#        {'name': 'Eastern Michigan Eagles', 'price': 500000},
#        {'name': 'Western Michigan Broncos', 'price': 500000},
#        {'name': 'Charlotte 49ers', 'price': 500000},
#        {'name': 'Central Michigan Chippewas', 'price': 500000},
#        {'name': 'UTEP Miners', 'price': 500000},
#        {'name': 'Buffalo Bulls', 'price': 500000},
#        {'name': 'Ball State Cardinals', 'price': 500000},
#        {'name': 'Arkansas State Red Wolves', 'price': 500000},
#        {'name': 'Tulsa Golden Hurricane', 'price': 500000},
#        {'name': 'Temple Owls', 'price': 500000},
#        {'name': 'Southern Mississippi Golden Eagles', 'price': 500000},
#        {'name': 'Rice Owls', 'price': 500000},
#        {'name': 'Northern Illinois Huskies', 'price': 500000},
#        {'name': 'New Mexico Lobos', 'price': 500000},
#        {'name': 'Middle Tennessee Blue Raiders', 'price': 500000},
#        {'name': 'Louisiana Tech Bulldogs', 'price': 500000},
#        {'name': 'Hawaii Rainbow Warriors', 'price': 500000}]}]},
#    {'key': 'betmgm',
#     'title': 'BetMGM',
#     'last_update': '2024-02-17T09:07:32Z',
#     'markets': [{'key': 'outrights',
#       'last_update': '2024-02-17T09:07:32Z',
#       'outcomes': [{'name': 'Georgia Bulldogs', 'price': 350},
#        {'name': 'Ohio State Buckeyes', 'price': 500},
#        {'name': 'Texas Longhorns', 'price': 750},
#        {'name': 'Alabama Crimson Tide', 'price': 800},
#        {'name': 'Oregon Ducks', 'price': 1000},
#        {'name': 'Michigan Wolverines', 'price': 1100},
#        {'name': 'Ole Miss Rebels', 'price': 1100},
#        {'name': 'LSU Tigers', 'price': 1600},
#        {'name': 'Clemson Tigers', 'price': 2000},
#        {'name': 'Florida State Seminoles', 'price': 2000},
#        {'name': 'Penn State Nittany Lions', 'price': 2500},
#        {'name': 'Notre Dame Fighting Irish', 'price': 2500},
#        {'name': 'Oklahoma Sooners', 'price': 3500},
#        {'name': 'USC Trojans', 'price': 3500},
#        {'name': 'Missouri Tigers', 'price': 3500},
#        {'name': 'Miami Hurricanes', 'price': 3500},
#        {'name': 'Texas A&M Aggies', 'price': 4000},
#        {'name': 'Tennessee Volunteers', 'price': 5000},
#        {'name': 'Washington Huskies', 'price': 8000},
#        {'name': 'Utah Utes', 'price': 8000},
#        {'name': 'Louisville Cardinals', 'price': 10000},
#        {'name': 'Wisconsin Badgers', 'price': 10000},
#        {'name': 'Auburn Tigers', 'price': 10000},
#        {'name': 'Kansas State Wildcats', 'price': 10000},
#        {'name': 'Colorado Buffaloes', 'price': 10000},
#        {'name': 'Arizona Wildcats', 'price': 12500},
#        {'name': 'North Carolina Tar Heels', 'price': 15000},
#        {'name': 'Florida Gators', 'price': 15000},
#        {'name': 'Kansas Jayhawks', 'price': 15000},
#        {'name': 'TCU Horned Frogs', 'price': 15000},
#        {'name': 'UCLA Bruins', 'price': 15000},
#        {'name': 'Iowa Hawkeyes', 'price': 20000},
#        {'name': 'Iowa State Cyclones', 'price': 20000},
#        {'name': 'NC State Wolfpack', 'price': 20000},
#        {'name': 'Nebraska Cornhuskers', 'price': 20000},
#        {'name': 'Texas Tech Red Raiders', 'price': 20000},
#        {'name': 'West Virginia Mountaineers', 'price': 20000},
#        {'name': 'Arkansas Razorbacks', 'price': 30000},
#        {'name': 'Kentucky Wildcats', 'price': 30000},
#        {'name': 'Michigan State Spartans', 'price': 30000},
#        {'name': 'Minnesota Golden Gophers', 'price': 30000},
#        {'name': 'Oregon State Beavers', 'price': 30000},
#        {'name': 'Purdue Boilermakers', 'price': 30000},
#        {'name': 'South Carolina Gamecocks', 'price': 30000},
#        {'name': 'UCF Knights', 'price': 30000},
#        {'name': 'Wake Forest Demon Deacons', 'price': 30000},
#        {'name': 'Baylor Bears', 'price': 50000},
#        {'name': 'Cincinnati Bearcats', 'price': 50000},
#        {'name': 'Houston Cougars', 'price': 50000},
#        {'name': 'Indiana Hoosiers', 'price': 50000},
#        {'name': 'Mississippi State Bulldogs', 'price': 50000},
#        {'name': 'Tulane Green Wave', 'price': 50000}]}]},
#    {'key': 'betrivers',
#     'title': 'BetRivers',
#     'last_update': '2024-02-17T09:08:39Z',
#     'markets': [{'key': 'outrights',
#       'last_update': '2024-02-17T09:08:39Z',
#       'outcomes': [{'name': 'Georgia Bulldogs', 'price': 350},
#        {'name': 'Ohio State Buckeyes', 'price': 550},
#        {'name': 'Texas Longhorns', 'price': 800},
#        {'name': 'Oregon Ducks', 'price': 850},
#        {'name': 'Alabama Crimson Tide', 'price': 1100},
#        {'name': 'Ole Miss Rebels', 'price': 1100},
#        {'name': 'Notre Dame Fighting Irish', 'price': 1400},
#        {'name': 'LSU Tigers', 'price': 1400},
#        {'name': 'Michigan Wolverines', 'price': 1600},
#        {'name': 'Penn State Nittany Lions', 'price': 2000},
#        {'name': 'Clemson Tigers', 'price': 2000},
#        {'name': 'Florida State Seminoles', 'price': 2500},
#        {'name': 'USC Trojans', 'price': 3000},
#        {'name': 'Tennessee Volunteers', 'price': 3000},
#        {'name': 'Texas A&M Aggies', 'price': 3000},
#        {'name': 'Missouri Tigers', 'price': 4000},
#        {'name': 'Oklahoma Sooners', 'price': 4500},
#        {'name': 'Auburn Tigers', 'price': 5000},
#        {'name': 'Washington Huskies', 'price': 5000},
#        {'name': 'Kansas State Wildcats', 'price': 6000},
#        {'name': 'Miami Hurricanes', 'price': 6000},
#        {'name': 'Utah Utes', 'price': 8000},
#        {'name': 'Louisville Cardinals', 'price': 10000},
#        {'name': 'Arizona Wildcats', 'price': 12000},
#        {'name': 'Wisconsin Badgers', 'price': 12000},
#        {'name': 'Florida Gators', 'price': 12000},
#        {'name': 'Texas Tech Red Raiders', 'price': 12000},
#        {'name': 'Arkansas Razorbacks', 'price': 15000},
#        {'name': 'Nebraska Cornhuskers', 'price': 15000},
#        {'name': 'North Carolina Tar Heels', 'price': 15000},
#        {'name': 'UCLA Bruins', 'price': 20000},
#        {'name': 'Kentucky Wildcats', 'price': 20000},
#        {'name': 'SMU Mustangs', 'price': 20000},
#        {'name': 'Colorado Buffaloes', 'price': 20000},
#        {'name': 'Kansas Jayhawks', 'price': 20000},
#        {'name': 'Oklahoma State Cowboys', 'price': 25000},
#        {'name': 'NC State Wolfpack', 'price': 25000},
#        {'name': 'South Carolina Gamecocks', 'price': 25000},
#        {'name': 'TCU Horned Frogs', 'price': 30000},
#        {'name': 'Michigan State Spartans', 'price': 30000},
#        {'name': 'UCF Knights', 'price': 40000},
#        {'name': 'Maryland Terrapins', 'price': 40000},
#        {'name': 'James Madison Dukes', 'price': 40000},
#        {'name': 'Iowa State Cyclones', 'price': 40000},
#        {'name': 'Virginia Tech Hokies', 'price': 40000},
#        {'name': 'Iowa Hawkeyes', 'price': 40000},
#        {'name': 'Cincinnati Bearcats', 'price': 50000},
#        {'name': 'Liberty Flames', 'price': 50000},
#        {'name': 'Mississippi State Bulldogs', 'price': 50000},
#        {'name': 'West Virginia Mountaineers', 'price': 50000},
#        {'name': 'Oregon State Beavers', 'price': 50000},
#        {'name': 'California Golden Bears', 'price': 50000},
#        {'name': 'Boise State Broncos', 'price': 60000},
#        {'name': 'Troy Trojans', 'price': 70000},
#        {'name': 'Baylor Bears', 'price': 70000},
#        {'name': 'Tulane Green Wave', 'price': 70000},
#        {'name': 'Pittsburgh Panthers', 'price': 80000},
#        {'name': 'Virginia Cavaliers', 'price': 80000},
#        {'name': 'Rutgers Scarlet Knights', 'price': 80000},
#        {'name': 'Memphis Tigers', 'price': 80000},
#        {'name': 'Minnesota Golden Gophers', 'price': 80000},
#        {'name': 'Vanderbilt Commodores', 'price': 80000},
#        {'name': 'Illinois Fighting Illini', 'price': 80000},
#        {'name': 'Arizona State Sun Devils', 'price': 80000},
#        {'name': 'Temple Owls', 'price': 80000},
#        {'name': 'Boston College Eagles', 'price': 80000},
#        {'name': 'Syracuse Orange', 'price': 80000},
#        {'name': 'Miami (OH) RedHawks', 'price': 80000},
#        {'name': 'Washington State Cougars', 'price': 80000},
#        {'name': 'San Diego State Aztecs', 'price': 100000},
#        {'name': 'Rice Owls', 'price': 100000},
#        {'name': 'East Carolina Pirates', 'price': 100000},
#        {'name': 'Purdue Boilermakers', 'price': 100000},
#        {'name': 'New Mexico State Aggies', 'price': 100000},
#        {'name': 'Coastal Carolina Chanticleers', 'price': 100000},
#        {'name': 'Louisiana Ragin Cajuns', 'price': 100000},
#        {'name': 'UMass Minutemen', 'price': 100000},
#        {'name': 'Houston Cougars', 'price': 100000},
#        {'name': 'Texas State Bobcats', 'price': 100000},
#        {'name': 'Charlotte 49ers', 'price': 100000},
#        {'name': 'UTSA Roadrunners', 'price': 100000},
#        {'name': 'South Alabama Jaguars', 'price': 100000},
#        {'name': 'Western Michigan Broncos', 'price': 100000},
#        {'name': 'UTEP Miners', 'price': 100000},
#        {'name': 'Fresno State Bulldogs', 'price': 100000},
#        {'name': 'Georgia Tech Yellow Jackets', 'price': 100000},
#        {'name': 'Georgia State Panthers', 'price': 100000},
#        {'name': 'Northwestern Wildcats', 'price': 100000},
#        {'name': 'Florida Atlantic Owls', 'price': 100000},
#        {'name': 'Western Kentucky Hilltoppers', 'price': 100000},
#        {'name': 'Ohio Bobcats', 'price': 100000},
#        {'name': 'Southern Mississippi Golden Eagles', 'price': 100000},
#        {'name': 'Central Michigan Chippewas', 'price': 100000},
#        {'name': 'BYU Cougars', 'price': 100000},
#        {'name': 'Buffalo Bulls', 'price': 100000},
#        {'name': 'Ball State Cardinals', 'price': 100000},
#        {'name': 'Toledo Rockets', 'price': 100000},
#        {'name': 'UL Monroe Warhawks', 'price': 100000},
#        {'name': 'Colorado State Rams', 'price': 100000},
#        {'name': 'Hawaii Rainbow Warriors', 'price': 100000},
#        {'name': 'Marshall Thundering Herd', 'price': 100000},
#        {'name': 'Wyoming Cowboys', 'price': 100000},
#        {'name': 'UAB Blazers', 'price': 100000},
#        {'name': 'UConn Huskies', 'price': 100000},
#        {'name': 'Wake Forest Demon Deacons', 'price': 100000},
#        {'name': 'Navy Midshipmen', 'price': 100000},
#        {'name': 'San Jose State Spartans', 'price': 100000},
#        {'name': 'Kent State Golden Flashes', 'price': 100000},
#        {'name': 'Eastern Michigan Eagles', 'price': 100000},
#        {'name': 'Arkansas State Red Wolves', 'price': 100000},
#        {'name': 'Indiana Hoosiers', 'price': 100000},
#        {'name': 'Nevada Wolf Pack', 'price': 100000},
#        {'name': 'North Texas Mean Green', 'price': 100000},
#        {'name': 'Air Force Falcons', 'price': 100000},
#        {'name': 'Army Black Knights', 'price': 100000},
#        {'name': 'Bowling Green Falcons', 'price': 100000},
#        {'name': 'Old Dominion Monarchs', 'price': 100000},
#        {'name': 'Utah State Aggies', 'price': 100000},
#        {'name': 'Duke Blue Devils', 'price': 100000},
#        {'name': 'UNLV Rebels', 'price': 100000},
#        {'name': 'Florida International Panthers', 'price': 100000},
#        {'name': 'Northern Illinois Huskies', 'price': 100000},
#        {'name': 'Akron Zips', 'price': 100000},
#        {'name': 'Georgia Southern Eagles', 'price': 100000},
#        {'name': 'New Mexico Lobos', 'price': 100000},
#        {'name': 'Middle Tennessee Blue Raiders', 'price': 100000},
#        {'name': 'Appalachian State Mountaineers', 'price': 100000},
#        {'name': 'Stanford Cardinal', 'price': 100000},
#        {'name': 'South Florida Bulls', 'price': 100000},
#        {'name': 'Louisiana Tech Bulldogs', 'price': 100000}]}]}]}]

# %%
odds_pd = pd.json_normalize(
    odds_json, 
    meta = [
    'id', 
    'sport_key', 
    'sport_title', 
    'commence_time', 
    'home_team', 
    'away_team',
    ['key', 'title']
    ],
    meta_prefix= 'top_level.',
    record_path = ['bookmakers', 'markets', 'outcomes']
    )

odds_pd = pd.merge(
    odds_pd,
    odds_pd.groupby(
    ['top_level.id', 'top_level.key.title']
    )['price'].max().reset_index().rename(columns = {'price': 'max_price'}),
    how = 'left',
    on = ['top_level.id', 'top_level.key.title']
)

odds_pd = pd.merge(
    odds_pd,
    odds_pd.groupby(
    ['top_level.id', 'top_level.key.title']
    )['price'].min().reset_index().rename(columns = {'price': 'min_price'}),
    how = 'left',
    on = ['top_level.id', 'top_level.key.title']
)

odds_pd.loc[odds_pd['price'] == odds_pd['min_price'], 'team_type'] = 'favorite'
odds_pd.loc[odds_pd['price'] == odds_pd['max_price'], 'team_type'] = 'underdog'


odds_pd['odds_id'] = [value1 + value2 for (value1, value2) in zip(
    odds_pd['top_level.id'].astype('str').to_list(), 
    odds_pd['top_level.key.title'].astype('str').to_list()
    )]

wide_pd = pd.pivot(odds_pd.reset_index(), 
    index = ['odds_id', 'name'],
    columns = ['team_type'],
    values = ['price']
).reset_index()
wide_pd.columns = [''.join(col) for col in wide_pd.columns.values]

wide_pd = wide_pd.groupby('odds_id').agg({'pricefavorite': 'max', 'priceunderdog': 'max'}).reset_index()

wide_pd['favorite_team_name'] = pd.merge(
    wide_pd,
    odds_pd[odds_pd['team_type'] == 'favorite'],
    how = 'left',
    on = 'odds_id'
)['name']

wide_pd['underdog_team_name'] = pd.merge(
    wide_pd,
    odds_pd[odds_pd['team_type'] == 'underdog'],
    how = 'left',
    on = 'odds_id'
)['name']

wide_pd = pd.merge(
    wide_pd,
    odds_pd.groupby('odds_id').agg({
    'top_level.sport_key': 'max',
    'top_level.sport_title': 'max',
    'top_level.commence_time': 'max',
    'top_level.away_team': 'max',
    'top_level.home_team': 'max',
    'top_level.key.title': 'max',
    'top_level.id': 'max'
}).reset_index(),
how = 'left',
on = 'odds_id')

wide_pd = wide_pd.rename(columns = {
    'pricefavorite': 'price_favorite',
    'priceunderdog': 'price_underdog',
    'top_level.sport_key': 'sport_key',
    'top_level.sport_title': 'sport_title',
    'top_level.commence_time': 'game_start_time',
    'top_level.away_team': 'away_team',
    'top_level.home_team': 'home_team',
    'top_level.key.title': 'bookie',
    'top_level.id': 'game_id'
    })

wide_pd.loc[pd.to_datetime(wide_pd['game_start_time']).dt.tz_localize(None) < datetime.utcnow(), 'live_ind'] = True
wide_pd.loc[pd.to_datetime(wide_pd['game_start_time']).dt.tz_localize(None) >= datetime.utcnow(), 'live_ind'] = False

# filter out live games
wide_pd = wide_pd[wide_pd['live_ind'] == False]


best_spread_pd = wide_pd.groupby(['game_id', 'home_team', 'away_team', 'sport_title', 'game_start_time', 'sport_key']).agg({
    'price_favorite': 'max', 
    'price_underdog': 'max'
    }).reset_index()

best_spread_pd = pd.merge(best_spread_pd,
                          wide_pd.groupby(['game_id', 'price_favorite']).agg({'bookie': lambda x: ', '.join(x)}).reset_index().rename(columns = {'bookie': 'price_favorite_bookies'}),
                          how = 'left', 
                          on = ['game_id', 'price_favorite'])

best_spread_pd = pd.merge(best_spread_pd,
                          wide_pd.groupby(['game_id', 'price_underdog']).agg({
    'bookie': lambda x: ', '.join(x)
    }).reset_index().rename(columns = {'bookie': 'price_underdog_bookies'}),
                          how = 'left', 
                          on = ['game_id', 'price_underdog'])

best_spread_pd['favorite_implied_prob'] = (abs(best_spread_pd['price_favorite']))/(abs(best_spread_pd['price_favorite'])+100)
best_spread_pd['underdog_implied_prob'] = 100/(abs(best_spread_pd['price_underdog'])+100)

best_spread_pd['arb_perc'] = best_spread_pd['favorite_implied_prob'] + best_spread_pd['underdog_implied_prob']

best_spread_pd['ud_over_fav_bet_proportion'] = best_spread_pd['underdog_implied_prob']/best_spread_pd['favorite_implied_prob']

# %%
best_spread_pd
# Out:
#                              game_id                 home_team
# 0   078070dc05d0e2ec50775183819cfd72  North Carolina Tar Heels  \
# 1   084c2c5e48cf85a7b81ebd3a29b377be            Duquesne Dukes
# 2   0a725739511f35563b0d4084206f0019      Detroit Mercy Titans
# 3   0cf434987ba19293a2a5f8377c169951        La Salle Explorers
# 4   16a389474eb307f58f24ad4f4642f27a             Dayton Flyers
# ..                               ...                       ...
# 59  e8a10f91d236f6b1861d7e49fc24b038            Columbia Lions
# 60  ec3bbaeab9f2bb6126da752c82c1056e       Oklahoma St Cowboys
# 61  ef5756f5e73d1caa1425a973c0425b3d           Houston Cougars
# 62  f1040990e303311b27fac1ad1d743bfe           Ole Miss Rebels
# 63  ffb610cc48a448bfe89cfa062fc23312          Colorado St Rams
#
#                   away_team sport_title       game_start_time
# 0      Virginia Tech Hokies       NCAAB  2024-02-17T19:00:00Z  \
# 1      Saint Joseph's Hawks       NCAAB  2024-02-17T19:30:00Z
# 2      Fort Wayne Mastodons       NCAAB  2024-02-17T18:00:00Z
# 3   Massachusetts Minutemen       NCAAB  2024-02-17T19:00:00Z
# 4              Fordham Rams       NCAAB  2024-02-17T18:30:00Z
# ..                      ...         ...                   ...
# 59      Dartmouth Big Green       NCAAB  2024-02-17T00:00:00Z
# 60              BYU Cougars       NCAAB  2024-02-17T19:00:00Z
# 61          Texas Longhorns       NCAAB  2024-02-17T18:00:00Z
# 62          Missouri Tigers       NCAAB  2024-02-18T01:30:00Z
# 63        Utah State Aggies       NCAAB  2024-02-17T22:30:00Z
#
#            sport_key  price_favorite  price_underdog   price_favorite_bookies
# 0   basketball_ncaab          -720.0           500.0                  FanDuel  \
# 1   basketball_ncaab          -180.0           152.0           PointsBet (US)
# 2   basketball_ncaab          -465.0           375.0                  FanDuel
# 3   basketball_ncaab          -210.0           175.0  FanDuel, PointsBet (US)
# 4   basketball_ncaab         -1799.0          1050.0           PointsBet (US)
# ..               ...             ...             ...                      ...
# 59  basketball_ncaab          -455.0           440.0                  Caesars
# 60  basketball_ncaab          -275.0           225.0  FanDuel, PointsBet (US)
# 61  basketball_ncaab          -800.0           550.0  FanDuel, PointsBet (US)
# 62  basketball_ncaab          -625.0           490.0        BetRivers, Unibet
# 63  basketball_ncaab          -178.0           150.0                  FanDuel
#
#      price_underdog_bookies  favorite_implied_prob  underdog_implied_prob
# 0   FanDuel, PointsBet (US)               0.878049               0.166667  \
# 1                   FanDuel               0.642857               0.396825
# 2            PointsBet (US)               0.823009               0.210526
# 3            PointsBet (US)               0.677419               0.363636
# 4            PointsBet (US)               0.947341               0.086957
# ..                      ...                    ...                    ...
# 59  BetOnline.ag, LowVig.ag               0.819820               0.185185
# 60        BetRivers, Unibet               0.733333               0.307692
# 61           PointsBet (US)               0.888889               0.153846
# 62                  FanDuel               0.862069               0.169492
# 63        BetRivers, Unibet               0.640288               0.400000
#
#     arb_perc  ud_over_fav_bet_proportion
# 0   1.044715                    0.189815
# 1   1.039683                    0.617284
# 2   1.033535                    0.255801
# 3   1.041056                    0.536797
# 4   1.034297                    0.091790
# ..       ...                         ...
# 59  1.005005                    0.225885
# 60  1.041026                    0.419580
# 61  1.042735                    0.173077
# 62  1.031560                    0.196610
# 63  1.040288                    0.624719
#
# [64 rows x 14 columns]
